# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

# %%
push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ## Spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf
# Out:
# (0.0:0.1:1.9000000000000001) Hz

# %%
Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ
# Out:
# (0.0:10.0:350.0)°

# %%
S = Spectrum(randn(Nf, Nθ)*m^2/Hz/°, f, θ)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   0.572503 m² °⁻¹ Hz⁻¹     1.79585 m² °⁻¹ Hz⁻¹    …  -0.866515 m² °⁻¹ Hz⁻¹
#   1.19864 m² °⁻¹ Hz⁻¹     -0.17659 m² °⁻¹ Hz⁻¹       -1.25429 m² °⁻¹ Hz⁻¹
#   1.24419 m² °⁻¹ Hz⁻¹     -0.10499 m² °⁻¹ Hz⁻¹        1.51887 m² °⁻¹ Hz⁻¹
#  -1.16935 m² °⁻¹ Hz⁻¹      0.578525 m² °⁻¹ Hz⁻¹       1.06096 m² °⁻¹ Hz⁻¹
#  -1.4616 m² °⁻¹ Hz⁻¹       1.00617 m² °⁻¹ Hz⁻¹       -0.0352887 m² °⁻¹ Hz⁻¹
# ...

# %% [markdown]
# ### Basic functions & properties

# %%
propertynames(S)
# Out:
# (:data, :axis1, :axis2, :coordinates, :axestypes, :axesnames)

# %%
S.axestypes
# Out:
# (:frequency, :direction)

# %%
S.axesnames
# Out:
# (:frequency, :direction)

# %%
S.coordinates
# Out:
# :polar

# %%
unit(S)
# Out:
# m² °⁻¹ Hz⁻¹

# %%
unit(S, :spectrum), unit(S, :axis1), unit(S, :axis2), unit(S, :integral)
# Out:
# (m² °⁻¹ Hz⁻¹, Hz, °, m²)

# %%
unit(S, :frequency) # can use axis names too
# Out:
# Hz

# %%
size(S), eltype(S)
# Out:
# ((20, 36), Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}})

# %%
axisinfo(S)
# Out:
# UndefVarError: `axisinfo` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X21sZmlsZQ==.jl:1

# %%
axisinfo(S.axis1)
# Out:
# UndefVarError: `axisinfo` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X22sZmlsZQ==.jl:1

# %% [markdown]
# ### Indexing

# %%
S[2:4, 1:5]
# Out:
# 3×5 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#   1.19864 m² °⁻¹ Hz⁻¹  -0.17659 m² °⁻¹ Hz⁻¹   …  -0.996509 m² °⁻¹ Hz⁻¹
#   1.24419 m² °⁻¹ Hz⁻¹  -0.10499 m² °⁻¹ Hz⁻¹      -1.07863 m² °⁻¹ Hz⁻¹
#  -1.16935 m² °⁻¹ Hz⁻¹   0.578525 m² °⁻¹ Hz⁻¹      0.603265 m² °⁻¹ Hz⁻¹

# %%
S[2, 4]
# Out:
# 0.30122361923546903 m² °⁻¹ Hz⁻¹

# %%
S[frequency=0.2Hz..0.5Hz] # if AxisArrays loaded
# Out:
# 4×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   1.24419 m² °⁻¹ Hz⁻¹     -0.10499 m² °⁻¹ Hz⁻¹   …   1.51887 m² °⁻¹ Hz⁻¹
#  -1.16935 m² °⁻¹ Hz⁻¹      0.578525 m² °⁻¹ Hz⁻¹      1.06096 m² °⁻¹ Hz⁻¹
#  -1.4616 m² °⁻¹ Hz⁻¹       1.00617 m² °⁻¹ Hz⁻¹      -0.0352887 m² °⁻¹ Hz⁻¹
#  -0.00572457 m² °⁻¹ Hz⁻¹   1.07087 m² °⁻¹ Hz⁻¹      -0.448302 m² °⁻¹ Hz⁻¹

# %%
S[frequency=0.1Hz..0.1Hz, direction=30°..30°]
# Out:
# 1×1 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.30122361923546903 m² °⁻¹ Hz⁻¹

# %%
S[frequency=2, direction=:]
# Out:
# 1×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  1.19864 m² °⁻¹ Hz⁻¹  -0.17659 m² °⁻¹ Hz⁻¹  …  -1.25429 m² °⁻¹ Hz⁻¹

# %%
S[0.4Hz, 10°..30°]
# Out:
# 1×3 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  1.00617 m² °⁻¹ Hz⁻¹  1.37295 m² °⁻¹ Hz⁻¹  0.301976 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ### Assignment

# %%
S2 = copy(S);

# %%
S2[2:4, 1:5] *= 100;
S2[2:4, 1:5]
# Out:
# 3×5 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#   119.864 m² °⁻¹ Hz⁻¹  -17.659 m² °⁻¹ Hz⁻¹   …   -99.6509 m² °⁻¹ Hz⁻¹
#   124.419 m² °⁻¹ Hz⁻¹  -10.499 m² °⁻¹ Hz⁻¹      -107.863 m² °⁻¹ Hz⁻¹
#  -116.935 m² °⁻¹ Hz⁻¹   57.8525 m² °⁻¹ Hz⁻¹       60.3265 m² °⁻¹ Hz⁻¹

# %%
S[2:4, 1:5]
# Out:
# 3×5 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#   1.19864 m² °⁻¹ Hz⁻¹  -0.17659 m² °⁻¹ Hz⁻¹   …  -0.996509 m² °⁻¹ Hz⁻¹
#   1.24419 m² °⁻¹ Hz⁻¹  -0.10499 m² °⁻¹ Hz⁻¹      -1.07863 m² °⁻¹ Hz⁻¹
#  -1.16935 m² °⁻¹ Hz⁻¹   0.578525 m² °⁻¹ Hz⁻¹      0.603265 m² °⁻¹ Hz⁻¹

# %%
S2[frequency=0.2Hz..0.2Hz, direction=10°..20°] = [99m^2/Hz/°, 99m^2/Hz/°]
# Out:
# 2-element Vector{Quantity{Int64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#  99 m² °⁻¹ Hz⁻¹
#  99 m² °⁻¹ Hz⁻¹

# %%
S2[0.2Hz, 10°..20°] = [99m^2 / Hz / °, 99m^2 / Hz / °]
# Out:
# 2-element Vector{Quantity{Int64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#  99 m² °⁻¹ Hz⁻¹
#  99 m² °⁻¹ Hz⁻¹

# %%
S2[0.2Hz, 20°] .= 100m^2/Hz/°
# Out:
# 1×1 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  100.0 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ##

# %% [markdown]
# ### Integrals

# %%
integrate(S, :axis2)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#   -31.419494750652063 m² Hz⁻¹
#   -27.42259224370511 m² Hz⁻¹
#    97.27388304551914 m² Hz⁻¹
#     3.976407651161433 m² Hz⁻¹
#    35.84437821982844 m² Hz⁻¹
#     3.2402433658265872 m² Hz⁻¹
#  -147.73156275027276 m² Hz⁻¹
#    70.74152805440116 m² Hz⁻¹
#   -45.57120673155984 m² Hz⁻¹
#     9.555612477283915 m² Hz⁻¹
#    -5.1311062935274325 m² Hz⁻¹
#    19.10776910045622 m² Hz⁻¹
#    35.05516027044255 m² Hz⁻¹
#    46.829598256062894 m² Hz⁻¹
#     8.175109504354351 m² Hz⁻¹
#    -9.623339113415662 m² Hz⁻¹
#   -71.50964427775678 m² Hz⁻¹
#   -40.701122041004126 m² Hz⁻¹
#   104.87223165918114 m² Hz⁻¹
#     8.549936927350915 m² Hz⁻¹

# %%
omnidirectional_spectrum = integrate(S, :direction)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#   -31.419494750652063 m² Hz⁻¹
#   -27.42259224370511 m² Hz⁻¹
#    97.27388304551914 m² Hz⁻¹
#     3.976407651161433 m² Hz⁻¹
#    35.84437821982844 m² Hz⁻¹
#     3.2402433658265872 m² Hz⁻¹
#  -147.73156275027276 m² Hz⁻¹
#    70.74152805440116 m² Hz⁻¹
#   -45.57120673155984 m² Hz⁻¹
#     9.555612477283915 m² Hz⁻¹
#    -5.1311062935274325 m² Hz⁻¹
#    19.10776910045622 m² Hz⁻¹
#    35.05516027044255 m² Hz⁻¹
#    46.829598256062894 m² Hz⁻¹
#     8.175109504354351 m² Hz⁻¹
#    -9.623339113415662 m² Hz⁻¹
#   -71.50964427775678 m² Hz⁻¹
#   -40.701122041004126 m² Hz⁻¹
#   104.87223165918114 m² Hz⁻¹
#     8.549936927350915 m² Hz⁻¹

# %%
integrate(S, :frequency)
# Out:
# ┌ Warning: Integration: The resulting vector is a function of direction, and is not returned as an 'OmnidirectionalSpectrum'.
# └ @ Spectra /Users/cmichel/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/integration.jl:21
# 36-element Vector{Quantity{Float64, 𝐋² 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, m²), 𝐋² 𝐀⁻¹, nothing}}}:
#  -0.19612918647893413 m² °⁻¹
#   0.49744180675578603 m² °⁻¹
#  -0.28146916210399325 m² °⁻¹
#  -0.4176888297144463 m² °⁻¹
#  -0.6313016572793742 m² °⁻¹
#   0.20145067420344387 m² °⁻¹
#   0.5469408859014294 m² °⁻¹
#  -0.5398686006390888 m² °⁻¹
#   0.5657489714385089 m² °⁻¹
#  -0.04972034850606255 m² °⁻¹
#   ⋮
#  -0.2518947105685281 m² °⁻¹
#  -0.34576640729401714 m² °⁻¹
#  -0.23537535767038734 m² °⁻¹
#  -0.22811495316676816 m² °⁻¹
#   0.5263599735270514 m² °⁻¹
#   0.27979024050518275 m² °⁻¹
#   0.012472718577777514 m² °⁻¹
#  -0.4519992274619331 m² °⁻¹
#   1.0299781941818136 m² °⁻¹

# %%
integrate(S)
# Out:
# 7.554656924162554 m²

# %% [markdown]
# ### Random

# %%
SC = Spectrum((randn(Nf, Nθ) + randn(Nf, Nθ)*im)*m^2/Hz/°, f, θ)
# Out:
# 20×36 Spectrum{Quantity{ComplexF64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   (0.361449+0.210295im) m² °⁻¹ Hz⁻¹   …    (0.536656-1.04358im) m² °⁻¹ Hz⁻¹
#  (-0.201975-1.04147im) m² °⁻¹ Hz⁻¹         (-1.50841-2.44098im) m² °⁻¹ Hz⁻¹
#  (-0.086264-0.706124im) m² °⁻¹ Hz⁻¹        (0.179019-0.123629im) m² °⁻¹ Hz⁻¹
#  (-0.894751+0.874636im) m² °⁻¹ Hz⁻¹         (-0.4105-0.450216im) m² °⁻¹ Hz⁻¹
#  (-0.261715+0.931497im) m² °⁻¹ Hz⁻¹        (0.643216-1.03648im) m² °⁻¹ Hz⁻¹
# ...

# %%
abs.(SC)
# Out:
# MethodError: no method matching axes(::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{Spectrum}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(abs), Tuple{Spectrum{Quantity{ComplexF64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}}})
#
# You may have intended to import Base.axes
#
#
#
# Closest candidates are:
#
#   axes(!Matched::OmnidirectionalSpectrum)
#
#    @ Spectra ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/functions.jl:30
#
# ...

# %%
angle.(°, SC)
# Out:
# MethodError: no method matching axes(::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{Spectrum}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(angle), Tuple{Base.RefValue{Unitful.FreeUnits{(°,), 𝐀, nothing}}, Spectrum{Quantity{ComplexF64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}}})
#
# You may have intended to import Base.axes
#
#
#
# Closest candidates are:
#
#   axes(!Matched::OmnidirectionalSpectrum)
#
# ...

# %%
S + S
# Out:
# MethodError: no method matching axes(::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{Spectrum}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(+), Tuple{Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, n
# ...

# %%
2S
# Out:
# MethodError: no method matching axes(::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{Spectrum}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(*), Tuple{Int64, Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}}})
#
# You may have intended to import Base.axes
#
#
#
# Closest candidates are:
#
#   axes(!Matched::OmnidirectionalSpectrum)
#
#    @ Spectra ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/functions.jl:30
#
# ...

# %%
try
    S .+ Spectrum(S.data, 2f, θ)
catch
    println("catch")
end
# Out:
# catch

# %% [markdown]
# ### Convert: units

# %%
S3 = Spectrum(randn(Nf, Nθ)m^2/Hz/°, collect(2f), collect(θ))
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  -0.210136 m² °⁻¹ Hz⁻¹    1.14241 m² °⁻¹ Hz⁻¹    …   0.0355658 m² °⁻¹ Hz⁻¹
#   1.66053 m² °⁻¹ Hz⁻¹     0.407657 m² °⁻¹ Hz⁻¹      -0.736382 m² °⁻¹ Hz⁻¹
#   0.20646 m² °⁻¹ Hz⁻¹    -0.433346 m² °⁻¹ Hz⁻¹       1.19247 m² °⁻¹ Hz⁻¹
#   0.176521 m² °⁻¹ Hz⁻¹   -1.15457 m² °⁻¹ Hz⁻¹       -1.06898 m² °⁻¹ Hz⁻¹
#  -1.04215 m² °⁻¹ Hz⁻¹     1.73063 m² °⁻¹ Hz⁻¹       -0.0643717 m² °⁻¹ Hz⁻¹
#   0.289191 m² °⁻¹ Hz⁻¹    0.161139 m² °⁻¹ Hz⁻¹   …   0.505685 m² °⁻¹ Hz⁻¹
#  -0.631326 m² °⁻¹ Hz⁻¹    1.00422 m² °⁻¹ Hz⁻¹        0.229886 m² °⁻¹ Hz⁻¹
#   0.0798373 m² °⁻¹ Hz⁻¹  -1.13741 m² °⁻¹ Hz⁻¹       -0.286671 m² °⁻¹ Hz⁻¹
#   0.574392 m² °⁻¹ Hz⁻¹    0.0154387 m² °⁻¹ Hz⁻¹      1.22552 m² °⁻¹ Hz⁻¹
#  -1.55074 m² °⁻¹ Hz⁻¹     0.632818 m² °⁻¹ Hz⁻¹      -0.84312 m² °⁻¹ Hz⁻¹
# ...

# %%
S3[1,1] = 1.2km^2/°/Hz;
S3
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#   1.2e6 m² °⁻¹ Hz⁻¹       1.14241 m² °⁻¹ Hz⁻¹    …   0.0355658 m² °⁻¹ Hz⁻¹
#   1.66053 m² °⁻¹ Hz⁻¹     0.407657 m² °⁻¹ Hz⁻¹      -0.736382 m² °⁻¹ Hz⁻¹
#   0.20646 m² °⁻¹ Hz⁻¹    -0.433346 m² °⁻¹ Hz⁻¹       1.19247 m² °⁻¹ Hz⁻¹
#   0.176521 m² °⁻¹ Hz⁻¹   -1.15457 m² °⁻¹ Hz⁻¹       -1.06898 m² °⁻¹ Hz⁻¹
#  -1.04215 m² °⁻¹ Hz⁻¹     1.73063 m² °⁻¹ Hz⁻¹       -0.0643717 m² °⁻¹ Hz⁻¹
#   0.289191 m² °⁻¹ Hz⁻¹    0.161139 m² °⁻¹ Hz⁻¹   …   0.505685 m² °⁻¹ Hz⁻¹
#  -0.631326 m² °⁻¹ Hz⁻¹    1.00422 m² °⁻¹ Hz⁻¹        0.229886 m² °⁻¹ Hz⁻¹
#   0.0798373 m² °⁻¹ Hz⁻¹  -1.13741 m² °⁻¹ Hz⁻¹       -0.286671 m² °⁻¹ Hz⁻¹
#   0.574392 m² °⁻¹ Hz⁻¹    0.0154387 m² °⁻¹ Hz⁻¹      1.22552 m² °⁻¹ Hz⁻¹
#  -1.55074 m² °⁻¹ Hz⁻¹     0.632818 m² °⁻¹ Hz⁻¹      -0.84312 m² °⁻¹ Hz⁻¹
# ...

# %%
uconvert.(km^2/Hz/°, S)
# Out:
# MethodError: no method matching axes(::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{Spectrum}, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}}, typeof(uconvert), Tuple{Base.RefValue{Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}}})
#
# You may have intended to import Base.axes
#
#
#
# Closest candidates are:
#
#   axes(!Matched::OmnidirectionalSpectrum)
#
# ...

# %%
SB = Spectrum(randn(Nf, Nθ)m^2 / Hz / °, collect(2f), collect(θ).|>rad)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(rad,), 𝐀, nothing}}}}:
#   0.484498 m² °⁻¹ Hz⁻¹    0.11852 m² °⁻¹ Hz⁻¹   …  -2.21515 m² °⁻¹ Hz⁻¹
#   1.04101 m² °⁻¹ Hz⁻¹    -0.698625 m² °⁻¹ Hz⁻¹     -1.13836 m² °⁻¹ Hz⁻¹
#  -1.85372 m² °⁻¹ Hz⁻¹     0.515567 m² °⁻¹ Hz⁻¹     -0.484731 m² °⁻¹ Hz⁻¹
#  -0.359556 m² °⁻¹ Hz⁻¹   -0.247877 m² °⁻¹ Hz⁻¹      0.0419688 m² °⁻¹ Hz⁻¹
#  -0.124449 m² °⁻¹ Hz⁻¹   -0.294825 m² °⁻¹ Hz⁻¹      1.52885 m² °⁻¹ Hz⁻¹
#   0.296945 m² °⁻¹ Hz⁻¹   -1.52987 m² °⁻¹ Hz⁻¹   …  -0.257919 m² °⁻¹ Hz⁻¹
#  -0.851271 m² °⁻¹ Hz⁻¹    2.0304 m² °⁻¹ Hz⁻¹       -0.897124 m² °⁻¹ Hz⁻¹
#   0.0851273 m² °⁻¹ Hz⁻¹  -0.455642 m² °⁻¹ Hz⁻¹      0.876022 m² °⁻¹ Hz⁻¹
#   2.27388 m² °⁻¹ Hz⁻¹    -1.73331 m² °⁻¹ Hz⁻¹       0.262995 m² °⁻¹ Hz⁻¹
#  -1.13641 m² °⁻¹ Hz⁻¹     0.139775 m² °⁻¹ Hz⁻¹      0.727082 m² °⁻¹ Hz⁻¹
# ...

# %%
integrate(SB)
# Out:
# 1.09052195550604 m² rad °⁻¹

# %%
upreferred(integrate(SB))
# Out:
# 62.482305516849436 m²

# %% [markdown]
# ### Convert: Quantities

# %%
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   0.572503 m² °⁻¹ Hz⁻¹     1.79585 m² °⁻¹ Hz⁻¹    …  -0.866515 m² °⁻¹ Hz⁻¹
#   1.19864 m² °⁻¹ Hz⁻¹     -0.17659 m² °⁻¹ Hz⁻¹       -1.25429 m² °⁻¹ Hz⁻¹
#   1.24419 m² °⁻¹ Hz⁻¹     -0.10499 m² °⁻¹ Hz⁻¹        1.51887 m² °⁻¹ Hz⁻¹
#  -1.16935 m² °⁻¹ Hz⁻¹      0.578525 m² °⁻¹ Hz⁻¹       1.06096 m² °⁻¹ Hz⁻¹
#  -1.4616 m² °⁻¹ Hz⁻¹       1.00617 m² °⁻¹ Hz⁻¹       -0.0352887 m² °⁻¹ Hz⁻¹
# ...

# %%
disp = Dispersion()
# Out:
# Dispersion(nothing, nothing)

# %%
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   0.572503 m² °⁻¹ Hz⁻¹     1.79585 m² °⁻¹ Hz⁻¹    …  -0.866515 m² °⁻¹ Hz⁻¹
#   1.19864 m² °⁻¹ Hz⁻¹     -0.17659 m² °⁻¹ Hz⁻¹       -1.25429 m² °⁻¹ Hz⁻¹
#   1.24419 m² °⁻¹ Hz⁻¹     -0.10499 m² °⁻¹ Hz⁻¹        1.51887 m² °⁻¹ Hz⁻¹
#  -1.16935 m² °⁻¹ Hz⁻¹      0.578525 m² °⁻¹ Hz⁻¹       1.06096 m² °⁻¹ Hz⁻¹
#  -1.4616 m² °⁻¹ Hz⁻¹       1.00617 m² °⁻¹ Hz⁻¹       -0.0352887 m² °⁻¹ Hz⁻¹
# ...

# %% [markdown]
# ## Broadcasting

# %%
S = Spectrum(randn(Nf, Nθ)*m^2/Hz/°, f, θ)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   2.0839 m² °⁻¹ Hz⁻¹       1.15678 m² °⁻¹ Hz⁻¹      …  -2.76526 m² °⁻¹ Hz⁻¹
#   0.468102 m² °⁻¹ Hz⁻¹     0.105896 m² °⁻¹ Hz⁻¹        -0.319658 m² °⁻¹ Hz⁻¹
#   0.52386 m² °⁻¹ Hz⁻¹      1.37604 m² °⁻¹ Hz⁻¹         -1.35211 m² °⁻¹ Hz⁻¹
#  -1.50905 m² °⁻¹ Hz⁻¹      0.961284 m² °⁻¹ Hz⁻¹        -0.736389 m² °⁻¹ Hz⁻¹
#  -1.0231 m² °⁻¹ Hz⁻¹       0.391552 m² °⁻¹ Hz⁻¹         1.16802 m² °⁻¹ Hz⁻¹
# ...

# %%
# omni = integrate(S, :direction)
omni = omnidirectional_spectrum(S)
# Out:
# MethodError: objects of type OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}} are not callable
#
# Use square brackets [] for indexing an Array.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y153sZmlsZQ==.jl:2

# %%
# spread = Spectrum(S ./ omnidirectional_spectrum, S.axis1, S.axis2)
spread = spread_function(S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹,), 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   4.29515 °⁻¹      2.38426 °⁻¹     …   0.0861883 °⁻¹    -5.6995 °⁻¹
#   0.0622489 °⁻¹    0.0140821 °⁻¹       0.136993 °⁻¹     -0.0425086 °⁻¹
#   1.59058 °⁻¹      4.17804 °⁻¹         0.429171 °⁻¹     -4.10538 °⁻¹
#   0.0669717 °⁻¹   -0.0426618 °⁻¹       0.0668075 °⁻¹     0.0326809 °⁻¹
#  -0.0119959 °⁻¹    0.00459096 °⁻¹      0.000167007 °⁻¹   0.0136951 °⁻¹
# ...

# %%
integrate(spread, :direction)
# Out:
# 20-element OmnidirectionalSpectrum{Float64, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#  1.000000000000007
#  0.999999999999999
#  0.999999999999968
#  0.9999999999999996
#  0.9999999999999998
#  0.9999999999999998
#  1.0000000000000009
#  1.0000000000000004
#  1.0000000000000002
#  0.9999999999999999
#  1.0
#  0.9999999999999993
#  1.000000000000004
#  0.9999999999999998
#  0.9999999999999998
#  0.9999999999999996
#  1.0000000000000002
#  1.0000000000000002
#  1.0000000000000002
#  0.9999999999999989

# %%
all(integrate(spread, :direction) .≈ 1)
# Out:
# MethodError: no method matching axes(::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{OmnidirectionalSpectrum}, Tuple{Base.OneTo{Int64}}, typeof(isapprox), Tuple{OmnidirectionalSpectrum{Float64, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}})
#
# You may have intended to import Base.axes
#
#
#
# Closest candidates are:
#
#   axes(!Matched::OmnidirectionalSpectrum)
#
#    @ Spectra ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/functions.jl:30
#
#   axes(!Matched::Spectrum)
#
#    @ Spectra ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/functions.jl:29
#
#
#
#
#
# Stacktrace:
#
#  [1] similar(bc::Base.Broadcast.Broadcasted{Base.Broadcast.ArrayStyle{OmnidirectionalSpectrum}, Tuple{Base.OneTo{Int64}}, typeof(isapprox), Tuple{OmnidirectionalSpectrum{Float64, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}}, ::Type{Bool})
#
# ...

# %%
S_reconstructed = spread .* omni
# Out:
# UndefVarError: `omni` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y201sZmlsZQ==.jl:1

# %%
all(S_reconstructed .≈ S)
# Out:
# UndefVarError: `S_reconstructed` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y203sZmlsZQ==.jl:1

# %% [markdown]
# ### Convert Units

# %%
uconvert.(u"s^-1", S.axis1)
# Out:
# 20-element Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(s⁻¹,), 𝐓⁻¹, nothing}}}:
#  0.0 s⁻¹
#  0.1 s⁻¹
#  0.2 s⁻¹
#  0.3 s⁻¹
#  0.4 s⁻¹
#  0.5 s⁻¹
#  0.6 s⁻¹
#  0.7 s⁻¹
#  0.8 s⁻¹
#  0.9 s⁻¹
#  1.0 s⁻¹
#  1.1 s⁻¹
#  1.2 s⁻¹
#  1.3 s⁻¹
#  1.4 s⁻¹
#  1.5 s⁻¹
#  1.6 s⁻¹
#  1.7 s⁻¹
#  1.8 s⁻¹
#  1.9 s⁻¹

# %%
axisinfo(S)
# Out:
# UndefVarError: `axisinfo` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y223sZmlsZQ==.jl:1

# %%
Spectra.axestypes(S)
# Out:
# (:frequency, :direction)

# %%
Spectra.axestypes(Hz)
# Out:
# :frequency

# %%
dimension(unit(S, :axis1))
# Out:
# 𝐓⁻¹

# %%
Tuple(Spectra.axesinfo(S)[i][2] for i∈1:2)
# Out:
# (𝐓⁻¹, 𝐀)

# %%
(Spectra.axesinfo(S)[1][2], Spectra.axesinfo(S)[2][2])

# %%
Spectra.axesinfo(S.axis1)[2]
# Out:
# 𝐓⁻¹

# %%
unit(S, :axis1)
# Out:
# Hz

# %%
dimension(Hz)
# Out:
# 𝐓⁻¹
