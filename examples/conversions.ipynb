# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ### create spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)
S[frequency=1] = zeros(Nθ) * m^2 / Hz / °;
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋^2 𝐓 𝐀^-1, Unitful.FreeUnits{(°^-1, Hz^-1, m^2), 𝐋^2 𝐓 𝐀^-1, nothing}}, StepRangeLen{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.0 m^2 °^-1 Hz^-1        …  0.0 m^2 °^-1 Hz^-1
#  0.0511768 m^2 °^-1 Hz^-1     0.69693 m^2 °^-1 Hz^-1
#  0.27516 m^2 °^-1 Hz^-1       0.753343 m^2 °^-1 Hz^-1
#  1.74287 m^2 °^-1 Hz^-1       0.445132 m^2 °^-1 Hz^-1
#  1.43198 m^2 °^-1 Hz^-1       1.34415 m^2 °^-1 Hz^-1
#  0.612568 m^2 °^-1 Hz^-1   …  0.631045 m^2 °^-1 Hz^-1
#  0.602846 m^2 °^-1 Hz^-1      0.842533 m^2 °^-1 Hz^-1
#  2.18698 m^2 °^-1 Hz^-1       0.502173 m^2 °^-1 Hz^-1
#  1.19775 m^2 °^-1 Hz^-1       1.18566 m^2 °^-1 Hz^-1
#  0.816322 m^2 °^-1 Hz^-1      0.506817 m^2 °^-1 Hz^-1
#  0.254809 m^2 °^-1 Hz^-1   …  0.560757 m^2 °^-1 Hz^-1
#  0.52382 m^2 °^-1 Hz^-1       1.33864 m^2 °^-1 Hz^-1
#  0.831845 m^2 °^-1 Hz^-1      1.51544 m^2 °^-1 Hz^-1
#  0.423842 m^2 °^-1 Hz^-1      1.27296 m^2 °^-1 Hz^-1
#  0.971486 m^2 °^-1 Hz^-1      1.22168 m^2 °^-1 Hz^-1
#  0.748683 m^2 °^-1 Hz^-1   …  0.491858 m^2 °^-1 Hz^-1
#  0.303428 m^2 °^-1 Hz^-1      0.753468 m^2 °^-1 Hz^-1
#  0.884192 m^2 °^-1 Hz^-1      0.330642 m^2 °^-1 Hz^-1
#  0.407388 m^2 °^-1 Hz^-1      0.661955 m^2 °^-1 Hz^-1
#  0.0331927 m^2 °^-1 Hz^-1     1.12071 m^2 °^-1 Hz^-1

# %% [markdown]
# ### convert

# %%
S_km = uconvert(u"km^2", S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋^2 𝐓 𝐀^-1, Unitful.FreeUnits{(°^-1, Hz^-1, km^2), 𝐋^2 𝐓 𝐀^-1, nothing}}, Vector{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 km^2 °^-1 Hz^-1         …  0.0 km^2 °^-1 Hz^-1
#  5.11768e-8 km^2 °^-1 Hz^-1     6.9693e-7 km^2 °^-1 Hz^-1
#  2.7516e-7 km^2 °^-1 Hz^-1      7.53343e-7 km^2 °^-1 Hz^-1
#  1.74287e-6 km^2 °^-1 Hz^-1     4.45132e-7 km^2 °^-1 Hz^-1
#  1.43198e-6 km^2 °^-1 Hz^-1     1.34415e-6 km^2 °^-1 Hz^-1
#  6.12568e-7 km^2 °^-1 Hz^-1  …  6.31045e-7 km^2 °^-1 Hz^-1
#  6.02846e-7 km^2 °^-1 Hz^-1     8.42533e-7 km^2 °^-1 Hz^-1
#  2.18698e-6 km^2 °^-1 Hz^-1     5.02173e-7 km^2 °^-1 Hz^-1
#  1.19775e-6 km^2 °^-1 Hz^-1     1.18566e-6 km^2 °^-1 Hz^-1
#  8.16322e-7 km^2 °^-1 Hz^-1     5.06817e-7 km^2 °^-1 Hz^-1
#  2.54809e-7 km^2 °^-1 Hz^-1  …  5.60757e-7 km^2 °^-1 Hz^-1
#  5.2382e-7 km^2 °^-1 Hz^-1      1.33864e-6 km^2 °^-1 Hz^-1
#  8.31845e-7 km^2 °^-1 Hz^-1     1.51544e-6 km^2 °^-1 Hz^-1
#  4.23842e-7 km^2 °^-1 Hz^-1     1.27296e-6 km^2 °^-1 Hz^-1
#  9.71486e-7 km^2 °^-1 Hz^-1     1.22168e-6 km^2 °^-1 Hz^-1
#  7.48683e-7 km^2 °^-1 Hz^-1  …  4.91858e-7 km^2 °^-1 Hz^-1
#  3.03428e-7 km^2 °^-1 Hz^-1     7.53468e-7 km^2 °^-1 Hz^-1
#  8.84192e-7 km^2 °^-1 Hz^-1     3.30642e-7 km^2 °^-1 Hz^-1
#  4.07388e-7 km^2 °^-1 Hz^-1     6.61955e-7 km^2 °^-1 Hz^-1
#  3.31927e-8 km^2 °^-1 Hz^-1     1.12071e-6 km^2 °^-1 Hz^-1

# %%
integrate(S), integrate(S_km), upreferred(integrate(S_km))
# Out:
# (497.3110423650579 m^2, 0.0004973110423650579 km^2, 497.3110423650579 m^2)

# %%
S_rad = uconvert(rad/s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋^2 𝐓 𝐀^-2, Unitful.FreeUnits{(°^-1, m^2, rad^-1, s), 𝐋^2 𝐓 𝐀^-2, nothing}}, Vector{Quantity{Float64, 𝐀 𝐓^-1, Unitful.FreeUnits{(rad, s^-1), 𝐀 𝐓^-1, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 m^2 s °^-1 rad^-1         …  0.0 m^2 s °^-1 rad^-1
#  0.00814504 m^2 s °^-1 rad^-1     0.11092 m^2 s °^-1 rad^-1
#  0.0437931 m^2 s °^-1 rad^-1      0.119898 m^2 s °^-1 rad^-1
#  0.277387 m^2 s °^-1 rad^-1       0.070845 m^2 s °^-1 rad^-1
#  0.227907 m^2 s °^-1 rad^-1       0.213927 m^2 s °^-1 rad^-1
#  0.0974932 m^2 s °^-1 rad^-1   …  0.100434 m^2 s °^-1 rad^-1
#  0.0959459 m^2 s °^-1 rad^-1      0.134093 m^2 s °^-1 rad^-1
#  0.348069 m^2 s °^-1 rad^-1       0.0799233 m^2 s °^-1 rad^-1
#  0.190627 m^2 s °^-1 rad^-1       0.188704 m^2 s °^-1 rad^-1
#  0.129922 m^2 s °^-1 rad^-1       0.0806624 m^2 s °^-1 rad^-1
#  0.0405541 m^2 s °^-1 rad^-1   …  0.0892472 m^2 s °^-1 rad^-1
#  0.0833685 m^2 s °^-1 rad^-1      0.213052 m^2 s °^-1 rad^-1
#  0.132392 m^2 s °^-1 rad^-1       0.241189 m^2 s °^-1 rad^-1
#  0.0674566 m^2 s °^-1 rad^-1      0.202597 m^2 s °^-1 rad^-1
#  0.154617 m^2 s °^-1 rad^-1       0.194436 m^2 s °^-1 rad^-1
#  0.119157 m^2 s °^-1 rad^-1    …  0.0782816 m^2 s °^-1 rad^-1
#  0.0482921 m^2 s °^-1 rad^-1      0.119918 m^2 s °^-1 rad^-1
#  0.140724 m^2 s °^-1 rad^-1       0.0526233 m^2 s °^-1 rad^-1
#  0.0648378 m^2 s °^-1 rad^-1      0.105353 m^2 s °^-1 rad^-1
#  0.00528278 m^2 s °^-1 rad^-1     0.178366 m^2 s °^-1 rad^-1

# %%
integrate(S_rad)
# Out:
# 497.3110423650579 m^2

# %%
S_T = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋^2 𝐀^-1 𝐓^-1, Unitful.FreeUnits{(°^-1, m^2, s^-1), 𝐋^2 𝐀^-1 𝐓^-1, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.119826 m^2 °^-1 s^-1     …  4.04575 m^2 °^-1 s^-1
#  1.31994 m^2 °^-1 s^-1         2.14473 m^2 °^-1 s^-1
#  2.55532 m^2 °^-1 s^-1         0.955556 m^2 °^-1 s^-1
#  0.776777 m^2 °^-1 s^-1        1.92888 m^2 °^-1 s^-1
#  1.68454 m^2 °^-1 s^-1         1.10668 m^2 °^-1 s^-1
#  1.90411 m^2 °^-1 s^-1      …  2.39449 m^2 °^-1 s^-1
#  0.716294 m^2 °^-1 s^-1        2.1513 m^2 °^-1 s^-1
#  1.19786 m^2 °^-1 s^-1         2.18223 m^2 °^-1 s^-1
#  0.633822 m^2 °^-1 s^-1        1.61976 m^2 °^-1 s^-1
#  0.254809 m^2 °^-1 s^-1        0.560757 m^2 °^-1 s^-1
#  0.661221 m^2 °^-1 s^-1     …  0.410522 m^2 °^-1 s^-1
#  0.766557 m^2 °^-1 s^-1        0.758825 m^2 °^-1 s^-1
#  1.07162 m^2 °^-1 s^-1         0.246065 m^2 °^-1 s^-1
#  0.217024 m^2 °^-1 s^-1        0.303312 m^2 °^-1 s^-1
#  0.153142 m^2 °^-1 s^-1        0.157761 m^2 °^-1 s^-1
#  0.229117 m^2 °^-1 s^-1     …  0.215063 m^2 °^-1 s^-1
#  0.156858 m^2 °^-1 s^-1        0.0400619 m^2 °^-1 s^-1
#  0.0110064 m^2 °^-1 s^-1       0.0301337 m^2 °^-1 s^-1
#  0.000511768 m^2 °^-1 s^-1     0.0069693 m^2 °^-1 s^-1
#  0.0 m^2 °^-1 s^-1             0.0 m^2 °^-1 s^-1

# %%
integrate(S_T[period=1:(Nf-1)])
# Out:
# 494.48931720875476 m^2

# %%
S_lin_freq = uconvert(Hz, :axis1, S)
integrate(S_lin_freq)
# Out:
# 497.3110423650579 m^2

# %%
S_T_2 = uconvert(s, :axis1, S_rad)
integrate(S_T_2[period=1:(Nf-1)])
# Out:
# 494.48931720875476 m^2

# %%
S_m = uconvert(m, :axis1, S, deepwater)
# Out:
# KeyError: key (𝐓^-1, 𝐋) not found
#
#
#
# Stacktrace:
#
#  [1] getindex
#
#    @ .\dict.jl:477 [inlined]
#
#  [2] getindex(::Dict{Tuple{Unitful.Dimensions, Unitful.Dimensions}, Function}, ::Unitful.Dimensions{(Unitful.Dimension{:Time}(-1//1),)}, ::Unitful.Dimensions{(Unitful.Dimension{:Length}(1//1),)})
#
#    @ Base .\abstractdict.jl:559
#
#  [3] uconvert(uq::Unitful.FreeUnits{(m^2,), 𝐋^2, nothing}, u1::Unitful.FreeUnits{(m,), 𝐋, nothing}, u2::Unitful.FreeUnits{(°,), 𝐀, nothing}, x::Spectrum{Quantity{Float64, 𝐋^2 𝐓 𝐀^-1, Unitful.FreeUnits{(°^-1, Hz^-1, m^2), 𝐋^2 𝐓 𝐀^-1, nothing}}, StepRangeLen{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra c:\Users\jtgrasb\Documents\GitHub\WaveSpectra\src\convert.jl:15
#
#  [4] uconvert(u::Unitful.FreeUnits{(m,), 𝐋, nothing}, s::Symbol, x::Spectrum{Quantity{Float64, 𝐋^2 𝐓 𝐀^-1, Unitful.FreeUnits{(°^-1, Hz^-1, m^2), 𝐋^2 𝐓 𝐀^-1, nothing}}, StepRangeLen{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓^-1, Unitful.FreeUnits{(Hz,), 𝐓^-1, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra c:\Users\jtgrasb\Documents\GitHub\WaveSpectra\src\convert.jl:47
#
#  [5] top-level scope
#
#    @ c:\Users\jtgrasb\Documents\GitHub\WaveSpectra\examples\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:1
