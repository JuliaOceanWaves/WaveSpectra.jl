# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ### create spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)
S[frequency=1] = zeros(Nθ) * m^2 / Hz / °;

# %% [markdown]
# ### convert

# %%
S_km = uconvert(u"km^2", S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 km² °⁻¹ Hz⁻¹         0.0 km² °⁻¹ Hz⁻¹         …  0.0 km² °⁻¹ Hz⁻¹
#  1.20703e-6 km² °⁻¹ Hz⁻¹  5.52967e-7 km² °⁻¹ Hz⁻¹     8.08828e-8 km² °⁻¹ Hz⁻¹
#  1.08521e-6 km² °⁻¹ Hz⁻¹  8.21261e-7 km² °⁻¹ Hz⁻¹     1.27508e-7 km² °⁻¹ Hz⁻¹
#  9.51075e-7 km² °⁻¹ Hz⁻¹  1.05127e-6 km² °⁻¹ Hz⁻¹     5.20586e-7 km² °⁻¹ Hz⁻¹
#  4.41414e-7 km² °⁻¹ Hz⁻¹  1.06883e-6 km² °⁻¹ Hz⁻¹     9.84437e-7 km² °⁻¹ Hz⁻¹
#  8.18261e-7 km² °⁻¹ Hz⁻¹  3.13156e-7 km² °⁻¹ Hz⁻¹  …  5.53557e-7 km² °⁻¹ Hz⁻¹
#  6.4888e-7 km² °⁻¹ Hz⁻¹   1.51107e-6 km² °⁻¹ Hz⁻¹     5.9741e-7 km² °⁻¹ Hz⁻¹
#  2.76988e-7 km² °⁻¹ Hz⁻¹  4.54528e-8 km² °⁻¹ Hz⁻¹     2.6469e-6 km² °⁻¹ Hz⁻¹
#  5.00802e-8 km² °⁻¹ Hz⁻¹  3.06884e-7 km² °⁻¹ Hz⁻¹     1.47094e-6 km² °⁻¹ Hz⁻¹
#  7.5508e-7 km² °⁻¹ Hz⁻¹   6.37258e-7 km² °⁻¹ Hz⁻¹     1.10033e-6 km² °⁻¹ Hz⁻¹
#  2.83205e-7 km² °⁻¹ Hz⁻¹  2.69756e-7 km² °⁻¹ Hz⁻¹  …  1.10949e-6 km² °⁻¹ Hz⁻¹
#  1.81633e-7 km² °⁻¹ Hz⁻¹  8.85516e-7 km² °⁻¹ Hz⁻¹     1.08221e-6 km² °⁻¹ Hz⁻¹
#  5.95715e-7 km² °⁻¹ Hz⁻¹  3.23779e-7 km² °⁻¹ Hz⁻¹     4.9696e-7 km² °⁻¹ Hz⁻¹
#  3.23418e-7 km² °⁻¹ Hz⁻¹  4.62403e-7 km² °⁻¹ Hz⁻¹     3.96299e-7 km² °⁻¹ Hz⁻¹
#  1.43484e-6 km² °⁻¹ Hz⁻¹  1.10008e-6 km² °⁻¹ Hz⁻¹     9.72773e-7 km² °⁻¹ Hz⁻¹
#  9.02852e-8 km² °⁻¹ Hz⁻¹  1.43128e-6 km² °⁻¹ Hz⁻¹  …  5.44541e-7 km² °⁻¹ Hz⁻¹
#  8.07984e-7 km² °⁻¹ Hz⁻¹  1.34877e-6 km² °⁻¹ Hz⁻¹     2.363e-7 km² °⁻¹ Hz⁻¹
#  3.58933e-7 km² °⁻¹ Hz⁻¹  2.31766e-6 km² °⁻¹ Hz⁻¹     1.20732e-6 km² °⁻¹ Hz⁻¹
#  6.06782e-7 km² °⁻¹ Hz⁻¹  4.16351e-7 km² °⁻¹ Hz⁻¹     4.16312e-7 km² °⁻¹ Hz⁻¹
#  4.29523e-7 km² °⁻¹ Hz⁻¹  1.15967e-6 km² °⁻¹ Hz⁻¹     2.67177e-7 km² °⁻¹ Hz⁻¹

# %%
integrate(S), integrate(S_km), upreferred(integrate(S_km))
# Out:
# (498.54492777236527 m², 0.0004985449277723651 km², 498.5449277723651 m²)

# %%
S_rad = uconvert(rad/s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m², rad⁻¹, s), 𝐋² 𝐓 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐓⁻¹, Unitful.FreeUnits{(rad, s⁻¹), 𝐀 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 m² s °⁻¹ rad⁻¹         …  0.0 m² s °⁻¹ rad⁻¹
#  0.192105 m² s °⁻¹ rad⁻¹       0.0128729 m² s °⁻¹ rad⁻¹
#  0.172717 m² s °⁻¹ rad⁻¹       0.0202936 m² s °⁻¹ rad⁻¹
#  0.151368 m² s °⁻¹ rad⁻¹       0.0828538 m² s °⁻¹ rad⁻¹
#  0.0702532 m² s °⁻¹ rad⁻¹      0.156678 m² s °⁻¹ rad⁻¹
#  0.13023 m² s °⁻¹ rad⁻¹     …  0.0881013 m² s °⁻¹ rad⁻¹
#  0.103272 m² s °⁻¹ rad⁻¹       0.0950808 m² s °⁻¹ rad⁻¹
#  0.044084 m² s °⁻¹ rad⁻¹       0.421267 m² s °⁻¹ rad⁻¹
#  0.00797051 m² s °⁻¹ rad⁻¹     0.234107 m² s °⁻¹ rad⁻¹
#  0.120175 m² s °⁻¹ rad⁻¹       0.175124 m² s °⁻¹ rad⁻¹
#  0.0450735 m² s °⁻¹ rad⁻¹   …  0.176581 m² s °⁻¹ rad⁻¹
#  0.0289077 m² s °⁻¹ rad⁻¹      0.172239 m² s °⁻¹ rad⁻¹
#  0.094811 m² s °⁻¹ rad⁻¹       0.0790936 m² s °⁻¹ rad⁻¹
#  0.0514736 m² s °⁻¹ rad⁻¹      0.0630729 m² s °⁻¹ rad⁻¹
#  0.228362 m² s °⁻¹ rad⁻¹       0.154822 m² s °⁻¹ rad⁻¹
#  0.0143693 m² s °⁻¹ rad⁻¹   …  0.0866664 m² s °⁻¹ rad⁻¹
#  0.128595 m² s °⁻¹ rad⁻¹       0.0376084 m² s °⁻¹ rad⁻¹
#  0.0571259 m² s °⁻¹ rad⁻¹      0.192152 m² s °⁻¹ rad⁻¹
#  0.0965724 m² s °⁻¹ rad⁻¹      0.0662581 m² s °⁻¹ rad⁻¹
#  0.0683608 m² s °⁻¹ rad⁻¹      0.0425226 m² s °⁻¹ rad⁻¹

# %%
integrate(S_rad)
# Out:
# 498.54492777236527 m²

# %%
S_T = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  1.55058 m² °⁻¹ s⁻¹    4.18641 m² °⁻¹ s⁻¹     …  0.96451 m² °⁻¹ s⁻¹
#  1.96597 m² °⁻¹ s⁻¹    1.34898 m² °⁻¹ s⁻¹        1.34885 m² °⁻¹ s⁻¹
#  1.03732 m² °⁻¹ s⁻¹    6.69804 m² °⁻¹ s⁻¹        3.48917 m² °⁻¹ s⁻¹
#  2.06844 m² °⁻¹ s⁻¹    3.45285 m² °⁻¹ s⁻¹        0.604929 m² °⁻¹ s⁻¹
#  0.203142 m² °⁻¹ s⁻¹   3.22038 m² °⁻¹ s⁻¹        1.22522 m² °⁻¹ s⁻¹
#  2.81229 m² °⁻¹ s⁻¹    2.15615 m² °⁻¹ s⁻¹     …  1.90664 m² °⁻¹ s⁻¹
#  0.546577 m² °⁻¹ s⁻¹   0.781461 m² °⁻¹ s⁻¹       0.669745 m² °⁻¹ s⁻¹
#  0.85783 m² °⁻¹ s⁻¹    0.466242 m² °⁻¹ s⁻¹       0.715622 m² °⁻¹ s⁻¹
#  0.219775 m² °⁻¹ s⁻¹   1.07147 m² °⁻¹ s⁻¹        1.30947 m² °⁻¹ s⁻¹
#  0.283205 m² °⁻¹ s⁻¹   0.269756 m² °⁻¹ s⁻¹       1.10949 m² °⁻¹ s⁻¹
#  0.611615 m² °⁻¹ s⁻¹   0.516179 m² °⁻¹ s⁻¹    …  0.89127 m² °⁻¹ s⁻¹
#  0.0320513 m² °⁻¹ s⁻¹  0.196406 m² °⁻¹ s⁻¹       0.9414 m² °⁻¹ s⁻¹
#  0.135724 m² °⁻¹ s⁻¹   0.0222719 m² °⁻¹ s⁻¹      1.29698 m² °⁻¹ s⁻¹
#  0.233597 m² °⁻¹ s⁻¹   0.543985 m² °⁻¹ s⁻¹       0.215068 m² °⁻¹ s⁻¹
#  0.204565 m² °⁻¹ s⁻¹   0.0782891 m² °⁻¹ s⁻¹      0.138389 m² °⁻¹ s⁻¹
#  0.0706262 m² °⁻¹ s⁻¹  0.171013 m² °⁻¹ s⁻¹    …  0.15751 m² °⁻¹ s⁻¹
#  0.0855967 m² °⁻¹ s⁻¹  0.0946141 m² °⁻¹ s⁻¹      0.0468527 m² °⁻¹ s⁻¹
#  0.0434084 m² °⁻¹ s⁻¹  0.0328504 m² °⁻¹ s⁻¹      0.00510033 m² °⁻¹ s⁻¹
#  0.0120703 m² °⁻¹ s⁻¹  0.00552967 m² °⁻¹ s⁻¹     0.000808828 m² °⁻¹ s⁻¹
#  0.0 m² °⁻¹ s⁻¹        0.0 m² °⁻¹ s⁻¹            0.0 m² °⁻¹ s⁻¹

# %%
integrate(S_T[period=1:(Nf-1)])
# Out:
# 494.8427328732979 m²

# %%
S_m = uconvert(m, :axis1, S, deepwater)
# Out:
# KeyError: key (𝐓⁻¹, 𝐋) not found
#
#
#
# Stacktrace:
#
#  [1] getindex
#
#    @ ./dict.jl:498 [inlined]
#
#  [2] getindex(::Dict{Tuple{Unitful.Dimensions, Unitful.Dimensions}, Function}, ::Unitful.Dimensions{(Unitful.Dimension{:Time}(-1//1),)}, ::Unitful.Dimensions{(Unitful.Dimension{:Length}(1//1),)})
#
#    @ Base ./abstractdict.jl:553
#
#  [3] uconvert(uq::Unitful.FreeUnits{(m²,), 𝐋², nothing}, u1::Unitful.FreeUnits{(m,), 𝐋, nothing}, u2::Unitful.FreeUnits{(°,), 𝐀, nothing}, x::Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra ~/repos/JuliaOceanWaves/WaveSpectra/src/convert.jl:15
#
#  [4] uconvert(u::Unitful.FreeUnits{(m,), 𝐋, nothing}, s::Symbol, x::Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra ~/repos/JuliaOceanWaves/WaveSpectra/src/convert.jl:47
#
#  [5] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/WaveSpectra/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:1
