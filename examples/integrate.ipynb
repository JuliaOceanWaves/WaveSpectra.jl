# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %%
Nf = 20
Δf = 0.1Hz
f = (1:Nf) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)

ΔT = 0.1s
T = (1:Nf) * Δf
ST = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / s / °, T, θ)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.0621412 m² °⁻¹ s⁻¹  1.39867 m² °⁻¹ s⁻¹   …  0.695547 m² °⁻¹ s⁻¹
#  0.376407 m² °⁻¹ s⁻¹   1.49082 m² °⁻¹ s⁻¹      1.17303 m² °⁻¹ s⁻¹
#  0.279814 m² °⁻¹ s⁻¹   1.16992 m² °⁻¹ s⁻¹      0.801739 m² °⁻¹ s⁻¹
#  0.0310622 m² °⁻¹ s⁻¹  0.55199 m² °⁻¹ s⁻¹      0.384609 m² °⁻¹ s⁻¹
#  0.229681 m² °⁻¹ s⁻¹   1.49391 m² °⁻¹ s⁻¹      0.212343 m² °⁻¹ s⁻¹
# ...

# %%
integrate(S, Spectra.RectangularRule()), integrate(ST, Spectra.RectangularRule())
# Out:
# (574.0581293172834 m², 582.8004415964008 Hz m² s⁻¹)

# %%
STc = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  3.31146 m² °⁻¹ s⁻¹    1.6569 m² °⁻¹ s⁻¹      …  2.86143 m² °⁻¹ s⁻¹
#  0.030253 m² °⁻¹ s⁻¹   1.50081 m² °⁻¹ s⁻¹        2.57576 m² °⁻¹ s⁻¹
#  3.71536 m² °⁻¹ s⁻¹    1.66939 m² °⁻¹ s⁻¹        2.44194 m² °⁻¹ s⁻¹
#  1.2321 m² °⁻¹ s⁻¹     1.37218 m² °⁻¹ s⁻¹        0.456225 m² °⁻¹ s⁻¹
#  2.31988 m² °⁻¹ s⁻¹    2.45464 m² °⁻¹ s⁻¹        1.2492 m² °⁻¹ s⁻¹
#  0.0619813 m² °⁻¹ s⁻¹  3.18628 m² °⁻¹ s⁻¹     …  3.34387 m² °⁻¹ s⁻¹
#  1.26082 m² °⁻¹ s⁻¹    0.0351061 m² °⁻¹ s⁻¹      0.497689 m² °⁻¹ s⁻¹
#  3.22436 m² °⁻¹ s⁻¹    1.92286 m² °⁻¹ s⁻¹        1.00708 m² °⁻¹ s⁻¹
#  0.606995 m² °⁻¹ s⁻¹   0.590729 m² °⁻¹ s⁻¹       0.404473 m² °⁻¹ s⁻¹
#  1.27518 m² °⁻¹ s⁻¹    0.818411 m² °⁻¹ s⁻¹       1.0213 m² °⁻¹ s⁻¹
# ...

# %%
integrate(STc, Spectra.RectangularRule())
# Out:
# ArgumentError: Integrand must be evenly spaced.
#
#
#
# Stacktrace:
#
#  [1] find_weights(x::Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, ::RectangularRule)
#
#    @ Spectra ~/repos/JuliaOceanWaves/WaveSpectra/src/integration.jl:79
#
#  [2] init_cacheval
#
#    @ ~/.julia/packages/Integrals/Pgt48/src/sampled.jl:77 [inlined]
#
#  [3] #init#5
#
#    @ ~/.julia/packages/Integrals/Pgt48/src/common.jl:145 [inlined]
#
#  [4] init
#
#    @ ~/.julia/packages/Integrals/Pgt48/src/common.jl:139 [inlined]
#
#  [5] #solve#6
#
#    @ ~/.julia/packages/Integrals/Pgt48/src/common.jl:170 [inlined]
#
#  [6] solve
#
#    @ ~/.julia/packages/Integrals/Pgt48/src/common.jl:167 [inlined]
#
#  [7] integrate(x::OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓⁻¹, Unitful.FreeUnits{(m², s⁻¹), 𝐋² 𝐓⁻¹, nothing}}, Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, method::RectangularRule)
#
#    @ Spectra ~/repos/JuliaOceanWaves/WaveSpectra/src/integration.jl:39
#
# ...

# %%
Sfc = uconvert(Hz, :axis1, STc)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.45221 m² °⁻¹ Hz⁻¹     0.974828 m² °⁻¹ Hz⁻¹    …  0.550008 m² °⁻¹ Hz⁻¹
#  1.27963 m² °⁻¹ Hz⁻¹     0.835632 m² °⁻¹ Hz⁻¹       0.401526 m² °⁻¹ Hz⁻¹
#  0.216706 m² °⁻¹ Hz⁻¹    0.827166 m² °⁻¹ Hz⁻¹       0.458746 m² °⁻¹ Hz⁻¹
#  0.780835 m² °⁻¹ Hz⁻¹    0.57305 m² °⁻¹ Hz⁻¹        1.00981 m² °⁻¹ Hz⁻¹
#  0.749948 m² °⁻¹ Hz⁻¹    0.00570399 m² °⁻¹ Hz⁻¹     0.827199 m² °⁻¹ Hz⁻¹
#  0.676246 m² °⁻¹ Hz⁻¹    0.200348 m² °⁻¹ Hz⁻¹    …  1.27403 m² °⁻¹ Hz⁻¹
#  1.94637 m² °⁻¹ Hz⁻¹     1.47797 m² °⁻¹ Hz⁻¹        0.551662 m² °⁻¹ Hz⁻¹
#  3.0221 m² °⁻¹ Hz⁻¹      0.156384 m² °⁻¹ Hz⁻¹       0.644167 m² °⁻¹ Hz⁻¹
#  0.793187 m² °⁻¹ Hz⁻¹    1.18075 m² °⁻¹ Hz⁻¹        1.05909 m² °⁻¹ Hz⁻¹
#  0.0230112 m² °⁻¹ Hz⁻¹   0.0616226 m² °⁻¹ Hz⁻¹      1.82571 m² °⁻¹ Hz⁻¹
# ...

# %%
integrate(Sfc, Spectra.RectangularRule())
# Out:
# 574.0581293172836 m²

# %%
isevenlyspaced(integrate(ST, :axis2))
# Out:
# true
