# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ### create spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)
S[frequency=1] = zeros(Nθ) * m^2 / Hz / °;
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.0 m² °⁻¹ Hz⁻¹         0.0 m² °⁻¹ Hz⁻¹        …  0.0 m² °⁻¹ Hz⁻¹
#  0.635295 m² °⁻¹ Hz⁻¹    0.977238 m² °⁻¹ Hz⁻¹      1.23893 m² °⁻¹ Hz⁻¹
#  0.430135 m² °⁻¹ Hz⁻¹    0.801559 m² °⁻¹ Hz⁻¹      1.5576 m² °⁻¹ Hz⁻¹
#  0.350525 m² °⁻¹ Hz⁻¹    2.13449 m² °⁻¹ Hz⁻¹       0.727796 m² °⁻¹ Hz⁻¹
#  3.27924 m² °⁻¹ Hz⁻¹     0.70273 m² °⁻¹ Hz⁻¹       2.11243 m² °⁻¹ Hz⁻¹
# ...

# %% [markdown]
# ### convert

# %%
S_km = uconvert(u"km^2", S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 km² °⁻¹ Hz⁻¹         0.0 km² °⁻¹ Hz⁻¹         …  0.0 km² °⁻¹ Hz⁻¹
#  6.35295e-7 km² °⁻¹ Hz⁻¹  9.77238e-7 km² °⁻¹ Hz⁻¹     1.23893e-6 km² °⁻¹ Hz⁻¹
#  4.30135e-7 km² °⁻¹ Hz⁻¹  8.01559e-7 km² °⁻¹ Hz⁻¹     1.5576e-6 km² °⁻¹ Hz⁻¹
#  3.50525e-7 km² °⁻¹ Hz⁻¹  2.13449e-6 km² °⁻¹ Hz⁻¹     7.27796e-7 km² °⁻¹ Hz⁻¹
#  3.27924e-6 km² °⁻¹ Hz⁻¹  7.0273e-7 km² °⁻¹ Hz⁻¹      2.11243e-6 km² °⁻¹ Hz⁻¹
#  1.4389e-6 km² °⁻¹ Hz⁻¹   4.50101e-7 km² °⁻¹ Hz⁻¹  …  3.66805e-8 km² °⁻¹ Hz⁻¹
#  3.18225e-7 km² °⁻¹ Hz⁻¹  4.00826e-7 km² °⁻¹ Hz⁻¹     5.56206e-7 km² °⁻¹ Hz⁻¹
#  1.83541e-6 km² °⁻¹ Hz⁻¹  1.32082e-6 km² °⁻¹ Hz⁻¹     2.23852e-6 km² °⁻¹ Hz⁻¹
#  3.14729e-7 km² °⁻¹ Hz⁻¹  5.83052e-7 km² °⁻¹ Hz⁻¹     5.97356e-7 km² °⁻¹ Hz⁻¹
# ...

# %%
integrate(S), integrate(S_km), upreferred(integrate(S_km))
# Out:
# (526.5682265460692 m², 0.0005265682265460692 km², 526.5682265460691 m²)

# %%
S_rad = uconvert(rad/s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m², rad⁻¹, s), 𝐋² 𝐓 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐓⁻¹, Unitful.FreeUnits{(rad, s⁻¹), 𝐀 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 m² s °⁻¹ rad⁻¹          …  0.0 m² s °⁻¹ rad⁻¹
#  0.10111 m² s °⁻¹ rad⁻¹         0.197182 m² s °⁻¹ rad⁻¹
#  0.0684582 m² s °⁻¹ rad⁻¹       0.247899 m² s °⁻¹ rad⁻¹
#  0.0557879 m² s °⁻¹ rad⁻¹       0.115832 m² s °⁻¹ rad⁻¹
#  0.521907 m² s °⁻¹ rad⁻¹        0.336204 m² s °⁻¹ rad⁻¹
#  0.229008 m² s °⁻¹ rad⁻¹     …  0.00583788 m² s °⁻¹ rad⁻¹
#  0.0506471 m² s °⁻¹ rad⁻¹       0.0885229 m² s °⁻¹ rad⁻¹
#  0.292114 m² s °⁻¹ rad⁻¹        0.356272 m² s °⁻¹ rad⁻¹
#  0.0500907 m² s °⁻¹ rad⁻¹       0.0950721 m² s °⁻¹ rad⁻¹
#  0.0220756 m² s °⁻¹ rad⁻¹       0.00174111 m² s °⁻¹ rad⁻¹
#  0.000698209 m² s °⁻¹ rad⁻¹  …  0.195733 m² s °⁻¹ rad⁻¹
#  0.253283 m² s °⁻¹ rad⁻¹        0.0191761 m² s °⁻¹ rad⁻¹
# ...

# %%
integrate(S_rad)
# Out:
# 526.5682265460691 m²

# %%
S_T = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.182237 m² °⁻¹ s⁻¹    0.314747 m² °⁻¹ s⁻¹    …  7.59402 m² °⁻¹ s⁻¹
#  5.17316 m² °⁻¹ s⁻¹     0.375217 m² °⁻¹ s⁻¹       1.25174 m² °⁻¹ s⁻¹
#  5.47735 m² °⁻¹ s⁻¹     2.91958 m² °⁻¹ s⁻¹        4.88094 m² °⁻¹ s⁻¹
#  2.75924 m² °⁻¹ s⁻¹     3.48518 m² °⁻¹ s⁻¹        1.34116 m² °⁻¹ s⁻¹
#  2.30244 m² °⁻¹ s⁻¹     2.38569 m² °⁻¹ s⁻¹        4.96611 m² °⁻¹ s⁻¹
#  1.28907 m² °⁻¹ s⁻¹     2.50491 m² °⁻¹ s⁻¹     …  0.126031 m² °⁻¹ s⁻¹
#  1.49779 m² °⁻¹ s⁻¹     0.169512 m² °⁻¹ s⁻¹       2.77209 m² °⁻¹ s⁻¹
#  0.741345 m² °⁻¹ s⁻¹    1.7081 m² °⁻¹ s⁻¹         2.78239 m² °⁻¹ s⁻¹
#  1.92562 m² °⁻¹ s⁻¹     1.39548 m² °⁻¹ s⁻¹        0.145789 m² °⁻¹ s⁻¹
#  0.00438698 m² °⁻¹ s⁻¹  0.0465361 m² °⁻¹ s⁻¹      1.22983 m² °⁻¹ s⁻¹
# ...

# %%
integrate(S_T[period=1:(Nf-1)])
# Out:
# 525.1984941445121 m²

# %%
S_lin_freq = uconvert(Hz, :axis1, S)
integrate(S_lin_freq)
# Out:
# 526.5682265460692 m²

# %%
S_T_2 = uconvert(s, :axis1, S_rad)
integrate(S_T_2[period=1:(Nf-1)])
# Out:
# 525.198494144512 m²

# %%
S_T_3 = uconvert(s/rad, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², rad, s⁻¹), 𝐋² 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓 𝐀⁻¹, Unitful.FreeUnits{(rad⁻¹, s), 𝐓 𝐀⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#   1.14503 m² rad °⁻¹ s⁻¹    …  47.7146 m² rad °⁻¹ s⁻¹
#  32.504 m² rad °⁻¹ s⁻¹          7.86493 m² rad °⁻¹ s⁻¹
#  34.4152 m² rad °⁻¹ s⁻¹        30.6678 m² rad °⁻¹ s⁻¹
#  17.3368 m² rad °⁻¹ s⁻¹         8.42674 m² rad °⁻¹ s⁻¹
#  14.4667 m² rad °⁻¹ s⁻¹        31.203 m² rad °⁻¹ s⁻¹
#   8.09944 m² rad °⁻¹ s⁻¹    …   0.791876 m² rad °⁻¹ s⁻¹
#   9.41088 m² rad °⁻¹ s⁻¹       17.4175 m² rad °⁻¹ s⁻¹
#   4.65801 m² rad °⁻¹ s⁻¹       17.4823 m² rad °⁻¹ s⁻¹
#  12.099 m² rad °⁻¹ s⁻¹          0.916021 m² rad °⁻¹ s⁻¹
#   0.0275642 m² rad °⁻¹ s⁻¹      7.72724 m² rad °⁻¹ s⁻¹
#   0.705922 m² rad °⁻¹ s⁻¹   …   0.0556765 m² rad °⁻¹ s⁻¹
#   1.2656 m² rad °⁻¹ s⁻¹         2.40211 m² rad °⁻¹ s⁻¹
#   5.65078 m² rad °⁻¹ s⁻¹        6.89188 m² rad °⁻¹ s⁻¹
# ...

# %%
integrate(S_T_3[angular_period=1:Nf-1])
# Out:
# 525.1984941445119 m²

# %%
S_m = uconvert(m, :axis1, S, deepwater)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, m), 𝐋 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐋, Unitful.FreeUnits{(m,), 𝐋, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#    0.110922 m °⁻¹       0.191577 m °⁻¹     …    4.62226 m °⁻¹
#    2.98303 m °⁻¹        0.216363 m °⁻¹          0.721799 m °⁻¹
#    2.98297 m °⁻¹        1.59001 m °⁻¹           2.65816 m °⁻¹
#    1.41429 m °⁻¹        1.78638 m °⁻¹           0.687431 m °⁻¹
#    1.10639 m °⁻¹        1.1464 m °⁻¹            2.38636 m °⁻¹
#    0.578139 m °⁻¹       1.12344 m °⁻¹      …    0.0565242 m °⁻¹
#    0.623768 m °⁻¹       0.0705947 m °⁻¹         1.15446 m °⁻¹
#    0.284991 m °⁻¹       0.656636 m °⁻¹          1.06962 m °⁻¹
#    0.678566 m °⁻¹       0.491752 m °⁻¹          0.0513745 m °⁻¹
#    0.00140538 m °⁻¹     0.014908 m °⁻¹          0.39398 m °⁻¹
#    0.0323928 m °⁻¹      0.388358 m °⁻¹     …    0.00255484 m °⁻¹
# ...

# %%
integrate(S_m[wavelength=1:Nf-1])
# Out:
# 549.065996863411 m²

# %%
S_ma = uconvert(rad/m, :axis1, S, deepwater)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋³ 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m³, rad⁻¹), 𝐋³ 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐋⁻¹, Unitful.FreeUnits{(m⁻¹, rad), 𝐀 𝐋⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  NaN m³ °⁻¹ rad⁻¹            …  NaN m³ °⁻¹ rad⁻¹
#    0.789054 m³ °⁻¹ rad⁻¹          1.53878 m³ °⁻¹ rad⁻¹
#    0.26712 m³ °⁻¹ rad⁻¹           0.967287 m³ °⁻¹ rad⁻¹
#    0.145121 m³ °⁻¹ rad⁻¹          0.301314 m³ °⁻¹ rad⁻¹
#    1.01823 m³ °⁻¹ rad⁻¹           0.655924 m³ °⁻¹ rad⁻¹
#    0.357431 m³ °⁻¹ rad⁻¹     …    0.00911163 m³ °⁻¹ rad⁻¹
#    0.065874 m³ °⁻¹ rad⁻¹          0.115137 m³ °⁻¹ rad⁻¹
#    0.325661 m³ °⁻¹ rad⁻¹          0.397187 m³ °⁻¹ rad⁻¹
#    0.0488627 m³ °⁻¹ rad⁻¹         0.0927414 m³ °⁻¹ rad⁻¹
#    0.0191417 m³ °⁻¹ rad⁻¹         0.00150972 m³ °⁻¹ rad⁻¹
#    0.000544874 m³ °⁻¹ rad⁻¹  …    0.152748 m³ °⁻¹ rad⁻¹
#    0.17969 m³ °⁻¹ rad⁻¹           0.0136044 m³ °⁻¹ rad⁻¹
#    0.0532853 m³ °⁻¹ rad⁻¹         0.199988 m³ °⁻¹ rad⁻¹
# ...

# %%
integrate(S_ma[angular_wavenumber=2:Nf])
# Out:
# 518.402642025065 m²

# %%
S1 = S
S2 = uconvert(Hz, :axis1, S, deepwater)
S3 = uconvert(rad/m, :axis1, S2, deepwater)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋³ 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m³, rad⁻¹), 𝐋³ 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐋⁻¹, Unitful.FreeUnits{(m⁻¹, rad), 𝐀 𝐋⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  NaN m³ °⁻¹ rad⁻¹            …  NaN m³ °⁻¹ rad⁻¹
#    0.789054 m³ °⁻¹ rad⁻¹          1.53878 m³ °⁻¹ rad⁻¹
#    0.26712 m³ °⁻¹ rad⁻¹           0.967287 m³ °⁻¹ rad⁻¹
#    0.145121 m³ °⁻¹ rad⁻¹          0.301314 m³ °⁻¹ rad⁻¹
#    1.01823 m³ °⁻¹ rad⁻¹           0.655924 m³ °⁻¹ rad⁻¹
#    0.357431 m³ °⁻¹ rad⁻¹     …    0.00911163 m³ °⁻¹ rad⁻¹
#    0.065874 m³ °⁻¹ rad⁻¹          0.115137 m³ °⁻¹ rad⁻¹
#    0.325661 m³ °⁻¹ rad⁻¹          0.397187 m³ °⁻¹ rad⁻¹
#    0.0488627 m³ °⁻¹ rad⁻¹         0.0927414 m³ °⁻¹ rad⁻¹
#    0.0191417 m³ °⁻¹ rad⁻¹         0.00150972 m³ °⁻¹ rad⁻¹
#    0.000544874 m³ °⁻¹ rad⁻¹  …    0.152748 m³ °⁻¹ rad⁻¹
#    0.17969 m³ °⁻¹ rad⁻¹           0.0136044 m³ °⁻¹ rad⁻¹
#    0.0532853 m³ °⁻¹ rad⁻¹         0.199988 m³ °⁻¹ rad⁻¹
# ...

# %%
Spectra._get_gradients(rad/m, S2.axis1, deepwater)
# Out:
# 20-element Vector{Quantity{Float64, 𝐀 𝐓 𝐋⁻¹, Unitful.FreeUnits{(Hz⁻¹, m⁻¹, rad), 𝐀 𝐓 𝐋⁻¹, nothing}}}:
#   0.0 rad Hz⁻¹ m⁻¹
#   0.8051356498775306 rad Hz⁻¹ m⁻¹
#   1.6102712997550612 rad Hz⁻¹ m⁻¹
#   2.415406949632592 rad Hz⁻¹ m⁻¹
#   3.2205425995101225 rad Hz⁻¹ m⁻¹
#   4.025678249387654 rad Hz⁻¹ m⁻¹
#   4.830813899265184 rad Hz⁻¹ m⁻¹
#   5.6359495491427145 rad Hz⁻¹ m⁻¹
#   6.441085199020245 rad Hz⁻¹ m⁻¹
#   7.246220848897776 rad Hz⁻¹ m⁻¹
#   8.051356498775307 rad Hz⁻¹ m⁻¹
#   8.856492148652839 rad Hz⁻¹ m⁻¹
#   9.661627798530368 rad Hz⁻¹ m⁻¹
#  10.4667634484079 rad Hz⁻¹ m⁻¹
#  11.271899098285429 rad Hz⁻¹ m⁻¹
#  12.07703474816296 rad Hz⁻¹ m⁻¹
#  12.88217039804049 rad Hz⁻¹ m⁻¹
#  13.687306047918023 rad Hz⁻¹ m⁻¹
#  14.492441697795552 rad Hz⁻¹ m⁻¹
#  15.297577347673082 rad Hz⁻¹ m⁻¹
