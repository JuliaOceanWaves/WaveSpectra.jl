# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ### create spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (1:Nf) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  1.49309 m² °⁻¹ Hz⁻¹   0.846506 m² °⁻¹ Hz⁻¹   …  1.00846 m² °⁻¹ Hz⁻¹
#  1.30152 m² °⁻¹ Hz⁻¹   0.352018 m² °⁻¹ Hz⁻¹      1.68737 m² °⁻¹ Hz⁻¹
#  1.36853 m² °⁻¹ Hz⁻¹   0.906197 m² °⁻¹ Hz⁻¹      0.445569 m² °⁻¹ Hz⁻¹
#  2.54405 m² °⁻¹ Hz⁻¹   0.512784 m² °⁻¹ Hz⁻¹      1.22608 m² °⁻¹ Hz⁻¹
#  1.18933 m² °⁻¹ Hz⁻¹   0.137394 m² °⁻¹ Hz⁻¹      0.15561 m² °⁻¹ Hz⁻¹
#  1.272 m² °⁻¹ Hz⁻¹     1.48368 m² °⁻¹ Hz⁻¹    …  1.72522 m² °⁻¹ Hz⁻¹
#  0.518135 m² °⁻¹ Hz⁻¹  0.96067 m² °⁻¹ Hz⁻¹       0.0973603 m² °⁻¹ Hz⁻¹
#  0.321368 m² °⁻¹ Hz⁻¹  0.196389 m² °⁻¹ Hz⁻¹      1.76128 m² °⁻¹ Hz⁻¹
#  0.692686 m² °⁻¹ Hz⁻¹  0.382182 m² °⁻¹ Hz⁻¹      0.00586468 m² °⁻¹ Hz⁻¹
#  0.9902 m² °⁻¹ Hz⁻¹    1.23368 m² °⁻¹ Hz⁻¹       1.32413 m² °⁻¹ Hz⁻¹
#  0.313094 m² °⁻¹ Hz⁻¹  0.282672 m² °⁻¹ Hz⁻¹   …  1.05977 m² °⁻¹ Hz⁻¹
#  1.36895 m² °⁻¹ Hz⁻¹   0.645189 m² °⁻¹ Hz⁻¹      0.828505 m² °⁻¹ Hz⁻¹
#  1.19372 m² °⁻¹ Hz⁻¹   0.70446 m² °⁻¹ Hz⁻¹       0.566231 m² °⁻¹ Hz⁻¹
#  2.16041 m² °⁻¹ Hz⁻¹   0.0915997 m² °⁻¹ Hz⁻¹     1.5018 m² °⁻¹ Hz⁻¹
#  0.333759 m² °⁻¹ Hz⁻¹  0.307477 m² °⁻¹ Hz⁻¹      1.3572 m² °⁻¹ Hz⁻¹
#  0.23816 m² °⁻¹ Hz⁻¹   0.834597 m² °⁻¹ Hz⁻¹   …  1.06276 m² °⁻¹ Hz⁻¹
#  0.609142 m² °⁻¹ Hz⁻¹  1.05432 m² °⁻¹ Hz⁻¹       0.740808 m² °⁻¹ Hz⁻¹
#  0.478071 m² °⁻¹ Hz⁻¹  0.134279 m² °⁻¹ Hz⁻¹      0.66253 m² °⁻¹ Hz⁻¹
#  0.610584 m² °⁻¹ Hz⁻¹  1.26515 m² °⁻¹ Hz⁻¹       0.042208 m² °⁻¹ Hz⁻¹
#  0.625833 m² °⁻¹ Hz⁻¹  0.0823124 m² °⁻¹ Hz⁻¹     0.160702 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ### convert

# %%
S_km = uconvert(u"km^2", S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  1.49309e-6 km² °⁻¹ Hz⁻¹  8.46506e-7 km² °⁻¹ Hz⁻¹  …  1.00846e-6 km² °⁻¹ Hz⁻¹
#  1.30152e-6 km² °⁻¹ Hz⁻¹  3.52018e-7 km² °⁻¹ Hz⁻¹     1.68737e-6 km² °⁻¹ Hz⁻¹
#  1.36853e-6 km² °⁻¹ Hz⁻¹  9.06197e-7 km² °⁻¹ Hz⁻¹     4.45569e-7 km² °⁻¹ Hz⁻¹
#  2.54405e-6 km² °⁻¹ Hz⁻¹  5.12784e-7 km² °⁻¹ Hz⁻¹     1.22608e-6 km² °⁻¹ Hz⁻¹
#  1.18933e-6 km² °⁻¹ Hz⁻¹  1.37394e-7 km² °⁻¹ Hz⁻¹     1.5561e-7 km² °⁻¹ Hz⁻¹
#  1.272e-6 km² °⁻¹ Hz⁻¹    1.48368e-6 km² °⁻¹ Hz⁻¹  …  1.72522e-6 km² °⁻¹ Hz⁻¹
#  5.18135e-7 km² °⁻¹ Hz⁻¹  9.6067e-7 km² °⁻¹ Hz⁻¹      9.73603e-8 km² °⁻¹ Hz⁻¹
#  3.21368e-7 km² °⁻¹ Hz⁻¹  1.96389e-7 km² °⁻¹ Hz⁻¹     1.76128e-6 km² °⁻¹ Hz⁻¹
#  6.92686e-7 km² °⁻¹ Hz⁻¹  3.82182e-7 km² °⁻¹ Hz⁻¹     5.86468e-9 km² °⁻¹ Hz⁻¹
#  9.902e-7 km² °⁻¹ Hz⁻¹    1.23368e-6 km² °⁻¹ Hz⁻¹     1.32413e-6 km² °⁻¹ Hz⁻¹
#  3.13094e-7 km² °⁻¹ Hz⁻¹  2.82672e-7 km² °⁻¹ Hz⁻¹  …  1.05977e-6 km² °⁻¹ Hz⁻¹
#  1.36895e-6 km² °⁻¹ Hz⁻¹  6.45189e-7 km² °⁻¹ Hz⁻¹     8.28505e-7 km² °⁻¹ Hz⁻¹
#  1.19372e-6 km² °⁻¹ Hz⁻¹  7.0446e-7 km² °⁻¹ Hz⁻¹      5.66231e-7 km² °⁻¹ Hz⁻¹
#  2.16041e-6 km² °⁻¹ Hz⁻¹  9.15997e-8 km² °⁻¹ Hz⁻¹     1.5018e-6 km² °⁻¹ Hz⁻¹
#  3.33759e-7 km² °⁻¹ Hz⁻¹  3.07477e-7 km² °⁻¹ Hz⁻¹     1.3572e-6 km² °⁻¹ Hz⁻¹
#  2.3816e-7 km² °⁻¹ Hz⁻¹   8.34597e-7 km² °⁻¹ Hz⁻¹  …  1.06276e-6 km² °⁻¹ Hz⁻¹
#  6.09142e-7 km² °⁻¹ Hz⁻¹  1.05432e-6 km² °⁻¹ Hz⁻¹     7.40808e-7 km² °⁻¹ Hz⁻¹
#  4.78071e-7 km² °⁻¹ Hz⁻¹  1.34279e-7 km² °⁻¹ Hz⁻¹     6.6253e-7 km² °⁻¹ Hz⁻¹
#  6.10584e-7 km² °⁻¹ Hz⁻¹  1.26515e-6 km² °⁻¹ Hz⁻¹     4.2208e-8 km² °⁻¹ Hz⁻¹
#  6.25833e-7 km² °⁻¹ Hz⁻¹  8.23124e-8 km² °⁻¹ Hz⁻¹     1.60702e-7 km² °⁻¹ Hz⁻¹

# %%
integrate(S), integrate(S_km), upreferred(integrate(S_km))
# Out:
# (533.750014136311 m², 0.000533750014136311 km², 533.7500141363109 m²)

# %%
S_rad = uconvert(rad/s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m², rad⁻¹, s), 𝐋² 𝐓 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐓⁻¹, Unitful.FreeUnits{(rad, s⁻¹), 𝐀 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.237633 m² s °⁻¹ rad⁻¹   …  0.160501 m² s °⁻¹ rad⁻¹
#  0.207143 m² s °⁻¹ rad⁻¹      0.268553 m² s °⁻¹ rad⁻¹
#  0.217808 m² s °⁻¹ rad⁻¹      0.0709146 m² s °⁻¹ rad⁻¹
#  0.404898 m² s °⁻¹ rad⁻¹      0.195137 m² s °⁻¹ rad⁻¹
#  0.189287 m² s °⁻¹ rad⁻¹      0.0247662 m² s °⁻¹ rad⁻¹
#  0.202445 m² s °⁻¹ rad⁻¹   …  0.274577 m² s °⁻¹ rad⁻¹
#  0.0824637 m² s °⁻¹ rad⁻¹     0.0154954 m² s °⁻¹ rad⁻¹
#  0.0511474 m² s °⁻¹ rad⁻¹     0.280316 m² s °⁻¹ rad⁻¹
#  0.110244 m² s °⁻¹ rad⁻¹      0.000933393 m² s °⁻¹ rad⁻¹
#  0.157595 m² s °⁻¹ rad⁻¹      0.210743 m² s °⁻¹ rad⁻¹
#  0.0498305 m² s °⁻¹ rad⁻¹  …  0.168668 m² s °⁻¹ rad⁻¹
#  0.217876 m² s °⁻¹ rad⁻¹      0.131861 m² s °⁻¹ rad⁻¹
#  0.189987 m² s °⁻¹ rad⁻¹      0.0901184 m² s °⁻¹ rad⁻¹
#  0.343839 m² s °⁻¹ rad⁻¹      0.23902 m² s °⁻¹ rad⁻¹
#  0.0531194 m² s °⁻¹ rad⁻¹     0.216005 m² s °⁻¹ rad⁻¹
#  0.0379043 m² s °⁻¹ rad⁻¹  …  0.169143 m² s °⁻¹ rad⁻¹
#  0.0969479 m² s °⁻¹ rad⁻¹     0.117903 m² s °⁻¹ rad⁻¹
#  0.0760873 m² s °⁻¹ rad⁻¹     0.105445 m² s °⁻¹ rad⁻¹
#  0.0971775 m² s °⁻¹ rad⁻¹     0.00671762 m² s °⁻¹ rad⁻¹
#  0.0996045 m² s °⁻¹ rad⁻¹     0.0255765 m² s °⁻¹ rad⁻¹

# %%
integrate(S_rad)
# Out:
# 533.7500141363109 m²

# %%
S_T = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  2.50333 m² °⁻¹ s⁻¹    0.32925 m² °⁻¹ s⁻¹     …  0.642807 m² °⁻¹ s⁻¹
#  2.20421 m² °⁻¹ s⁻¹    4.56719 m² °⁻¹ s⁻¹        0.152371 m² °⁻¹ s⁻¹
#  1.54895 m² °⁻¹ s⁻¹    0.435065 m² °⁻¹ s⁻¹       2.1466 m² °⁻¹ s⁻¹
#  1.76042 m² °⁻¹ s⁻¹    3.04698 m² °⁻¹ s⁻¹        2.14093 m² °⁻¹ s⁻¹
#  0.609689 m² °⁻¹ s⁻¹   2.13657 m² °⁻¹ s⁻¹        2.72066 m² °⁻¹ s⁻¹
#  0.750958 m² °⁻¹ s⁻¹   0.691822 m² °⁻¹ s⁻¹    …  3.0537 m² °⁻¹ s⁻¹
#  4.2344 m² °⁻¹ s⁻¹     0.179535 m² °⁻¹ s⁻¹       2.94354 m² °⁻¹ s⁻¹
#  2.01739 m² °⁻¹ s⁻¹    1.19054 m² °⁻¹ s⁻¹        0.95693 m² °⁻¹ s⁻¹
#  1.97129 m² °⁻¹ s⁻¹    0.929073 m² °⁻¹ s⁻¹       1.19305 m² °⁻¹ s⁻¹
#  0.378844 m² °⁻¹ s⁻¹   0.342033 m² °⁻¹ s⁻¹       1.28233 m² °⁻¹ s⁻¹
#  0.9902 m² °⁻¹ s⁻¹     1.23368 m² °⁻¹ s⁻¹     …  1.32413 m² °⁻¹ s⁻¹
#  0.561076 m² °⁻¹ s⁻¹   0.309567 m² °⁻¹ s⁻¹       0.00475039 m² °⁻¹ s⁻¹
#  0.205676 m² °⁻¹ s⁻¹   0.125689 m² °⁻¹ s⁻¹       1.12722 m² °⁻¹ s⁻¹
#  0.253886 m² °⁻¹ s⁻¹   0.470728 m² °⁻¹ s⁻¹       0.0477065 m² °⁻¹ s⁻¹
#  0.457921 m² °⁻¹ s⁻¹   0.534125 m² °⁻¹ s⁻¹       0.621079 m² °⁻¹ s⁻¹
#  0.297332 m² °⁻¹ s⁻¹   0.0343485 m² °⁻¹ s⁻¹   …  0.0389026 m² °⁻¹ s⁻¹
#  0.407047 m² °⁻¹ s⁻¹   0.0820454 m² °⁻¹ s⁻¹      0.196173 m² °⁻¹ s⁻¹
#  0.123168 m² °⁻¹ s⁻¹   0.0815577 m² °⁻¹ s⁻¹      0.0401012 m² °⁻¹ s⁻¹
#  0.0520606 m² °⁻¹ s⁻¹  0.0140807 m² °⁻¹ s⁻¹      0.0674948 m² °⁻¹ s⁻¹
#  0.0149309 m² °⁻¹ s⁻¹  0.00846506 m² °⁻¹ s⁻¹     0.0100846 m² °⁻¹ s⁻¹

# %%
integrate(S_T)
# Out:
# 548.234365860857 m²

# %%
S_lin_freq = uconvert(Hz, :axis1, S)
integrate(S_lin_freq)
# Out:
# 533.750014136311 m²

# %%
S_T_2 = uconvert(s, :axis1, S_rad)
integrate(S_T_2)
# Out:
# 548.234365860857 m²

# %%
S_T_3 = uconvert(s/rad, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², rad, s⁻¹), 𝐋² 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓 𝐀⁻¹, Unitful.FreeUnits{(rad⁻¹, s), 𝐓 𝐀⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  15.7289 m² rad °⁻¹ s⁻¹     …   4.03888 m² rad °⁻¹ s⁻¹
#  13.8495 m² rad °⁻¹ s⁻¹         0.957375 m² rad °⁻¹ s⁻¹
#   9.73233 m² rad °⁻¹ s⁻¹       13.4875 m² rad °⁻¹ s⁻¹
#  11.061 m² rad °⁻¹ s⁻¹         13.4519 m² rad °⁻¹ s⁻¹
#   3.83079 m² rad °⁻¹ s⁻¹       17.0944 m² rad °⁻¹ s⁻¹
#   4.71841 m² rad °⁻¹ s⁻¹    …  19.187 m² rad °⁻¹ s⁻¹
#  26.6055 m² rad °⁻¹ s⁻¹        18.4948 m² rad °⁻¹ s⁻¹
#  12.6756 m² rad °⁻¹ s⁻¹         6.01257 m² rad °⁻¹ s⁻¹
#  12.386 m² rad °⁻¹ s⁻¹          7.49614 m² rad °⁻¹ s⁻¹
#   2.38035 m² rad °⁻¹ s⁻¹        8.05709 m² rad °⁻¹ s⁻¹
#   6.22161 m² rad °⁻¹ s⁻¹    …   8.31978 m² rad °⁻¹ s⁻¹
#   3.52534 m² rad °⁻¹ s⁻¹        0.0298476 m² rad °⁻¹ s⁻¹
#   1.2923 m² rad °⁻¹ s⁻¹         7.08253 m² rad °⁻¹ s⁻¹
#   1.59521 m² rad °⁻¹ s⁻¹        0.299749 m² rad °⁻¹ s⁻¹
#   2.8772 m² rad °⁻¹ s⁻¹         3.90235 m² rad °⁻¹ s⁻¹
#   1.86819 m² rad °⁻¹ s⁻¹    …   0.244432 m² rad °⁻¹ s⁻¹
#   2.55755 m² rad °⁻¹ s⁻¹        1.23259 m² rad °⁻¹ s⁻¹
#   0.773885 m² rad °⁻¹ s⁻¹       0.251964 m² rad °⁻¹ s⁻¹
#   0.327107 m² rad °⁻¹ s⁻¹       0.424082 m² rad °⁻¹ s⁻¹
#   0.0938137 m² rad °⁻¹ s⁻¹      0.0633631 m² rad °⁻¹ s⁻¹

# %%
integrate(S_T_3[angular_period=1:Nf-1])
# Out:
# 508.7795745568147 m²

# %%
S_m = uconvert(m, :axis1, S, deepwater)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, m), 𝐋 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐋, Unitful.FreeUnits{(m,), 𝐋, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  1.6039 m °⁻¹       0.210952 m °⁻¹     …  0.411851 m °⁻¹
#  1.34164 m °⁻¹      2.77992 m °⁻¹         0.0927439 m °⁻¹
#  0.89318 m °⁻¹      0.250874 m °⁻¹        1.23781 m °⁻¹
#  0.958726 m °⁻¹     1.65939 m °⁻¹         1.16595 m °⁻¹
#  0.312505 m °⁻¹     1.09513 m °⁻¹         1.39451 m °⁻¹
#  0.360858 m °⁻¹     0.332441 m °⁻¹     …  1.4674 m °⁻¹
#  1.8991 m °⁻¹       0.0805206 m °⁻¹       1.32016 m °⁻¹
#  0.840161 m °⁻¹     0.49581 m °⁻¹         0.398522 m °⁻¹
#  0.757812 m °⁻¹     0.357158 m °⁻¹        0.458636 m °⁻¹
#  0.1335 m °⁻¹       0.120528 m °⁻¹        0.451877 m °⁻¹
#  0.317214 m °⁻¹     0.395215 m °⁻¹     …  0.424191 m °⁻¹
#  0.161768 m °⁻¹     0.0892538 m °⁻¹       0.00136962 m °⁻¹
#  0.0527111 m °⁻¹    0.0322119 m °⁻¹       0.288887 m °⁻¹
#  0.0569332 m °⁻¹    0.10556 m °⁻¹         0.0106981 m °⁻¹
#  0.0880178 m °⁻¹    0.102665 m °⁻¹        0.119379 m °⁻¹
#  0.0476256 m °⁻¹    0.00550183 m °⁻¹   …  0.00623128 m °⁻¹
#  0.0521596 m °⁻¹    0.0105134 m °⁻¹       0.0251378 m °⁻¹
#  0.0118372 m °⁻¹    0.00783818 m °⁻¹      0.00385397 m °⁻¹
#  0.00333556 m °⁻¹   0.00090216 m °⁻¹      0.00432444 m °⁻¹
#  0.000478317 m °⁻¹  0.000271181 m °⁻¹     0.000323062 m °⁻¹

# %%
integrate(S_m)
# Out:
# 571.818114307325 m²

# %%
S_ma = uconvert(rad/m, :axis1, S, deepwater)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋³ 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m³, rad⁻¹), 𝐋³ 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐋⁻¹, Unitful.FreeUnits{(m⁻¹, rad), 𝐀 𝐋⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  1.85446 m³ °⁻¹ rad⁻¹    1.05138 m³ °⁻¹ rad⁻¹     …  1.25253 m³ °⁻¹ rad⁻¹
#  0.808259 m³ °⁻¹ rad⁻¹   0.218608 m³ °⁻¹ rad⁻¹       1.04788 m³ °⁻¹ rad⁻¹
#  0.566584 m³ °⁻¹ rad⁻¹   0.375173 m³ °⁻¹ rad⁻¹       0.18447 m³ °⁻¹ rad⁻¹
#  0.789943 m³ °⁻¹ rad⁻¹   0.159223 m³ °⁻¹ rad⁻¹       0.380706 m³ °⁻¹ rad⁻¹
#  0.295435 m³ °⁻¹ rad⁻¹   0.0341294 m³ °⁻¹ rad⁻¹      0.0386544 m³ °⁻¹ rad⁻¹
#  0.26331 m³ °⁻¹ rad⁻¹    0.307128 m³ °⁻¹ rad⁻¹    …  0.357128 m³ °⁻¹ rad⁻¹
#  0.0919338 m³ °⁻¹ rad⁻¹  0.170454 m³ °⁻¹ rad⁻¹       0.0172749 m³ °⁻¹ rad⁻¹
#  0.0498935 m³ °⁻¹ rad⁻¹  0.0304901 m³ °⁻¹ rad⁻¹      0.273445 m³ °⁻¹ rad⁻¹
#  0.0955927 m³ °⁻¹ rad⁻¹  0.0527422 m³ °⁻¹ rad⁻¹      0.000809344 m³ °⁻¹ rad⁻¹
#  0.122986 m³ °⁻¹ rad⁻¹   0.153227 m³ °⁻¹ rad⁻¹       0.164461 m³ °⁻¹ rad⁻¹
#  0.035352 m³ °⁻¹ rad⁻¹   0.0319169 m³ °⁻¹ rad⁻¹   …  0.119661 m³ °⁻¹ rad⁻¹
#  0.14169 m³ °⁻¹ rad⁻¹    0.0667785 m³ °⁻¹ rad⁻¹      0.0857522 m³ °⁻¹ rad⁻¹
#  0.114049 m³ °⁻¹ rad⁻¹   0.0673045 m³ °⁻¹ rad⁻¹      0.054098 m³ °⁻¹ rad⁻¹
#  0.191663 m³ °⁻¹ rad⁻¹   0.00812637 m³ °⁻¹ rad⁻¹     0.133234 m³ °⁻¹ rad⁻¹
#  0.0276359 m³ °⁻¹ rad⁻¹  0.0254596 m³ °⁻¹ rad⁻¹      0.112379 m³ °⁻¹ rad⁻¹
#  0.0184875 m³ °⁻¹ rad⁻¹  0.064787 m³ °⁻¹ rad⁻¹    …  0.0824983 m³ °⁻¹ rad⁻¹
#  0.0445041 m³ °⁻¹ rad⁻¹  0.077029 m³ °⁻¹ rad⁻¹       0.0541237 m³ °⁻¹ rad⁻¹
#  0.0329876 m³ °⁻¹ rad⁻¹  0.00926547 m³ °⁻¹ rad⁻¹     0.0457156 m³ °⁻¹ rad⁻¹
#  0.0399138 m³ °⁻¹ rad⁻¹  0.0827026 m³ °⁻¹ rad⁻¹      0.00275913 m³ °⁻¹ rad⁻¹
#  0.0388651 m³ °⁻¹ rad⁻¹  0.00511171 m³ °⁻¹ rad⁻¹     0.0099798 m³ °⁻¹ rad⁻¹

# %%
integrate(S_ma)
# Out:
# 540.3332526637703 m²

# %%
S2 = uconvert(rad / m, :axis1, S, deepwater)
S3 = uconvert(Hz, :axis1, S2, deepwater)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  1.49309 m² °⁻¹ Hz⁻¹   0.846506 m² °⁻¹ Hz⁻¹   …  1.00846 m² °⁻¹ Hz⁻¹
#  1.30152 m² °⁻¹ Hz⁻¹   0.352018 m² °⁻¹ Hz⁻¹      1.68737 m² °⁻¹ Hz⁻¹
#  1.36853 m² °⁻¹ Hz⁻¹   0.906197 m² °⁻¹ Hz⁻¹      0.445569 m² °⁻¹ Hz⁻¹
#  2.54405 m² °⁻¹ Hz⁻¹   0.512784 m² °⁻¹ Hz⁻¹      1.22608 m² °⁻¹ Hz⁻¹
#  1.18933 m² °⁻¹ Hz⁻¹   0.137394 m² °⁻¹ Hz⁻¹      0.15561 m² °⁻¹ Hz⁻¹
#  1.272 m² °⁻¹ Hz⁻¹     1.48368 m² °⁻¹ Hz⁻¹    …  1.72522 m² °⁻¹ Hz⁻¹
#  0.518135 m² °⁻¹ Hz⁻¹  0.96067 m² °⁻¹ Hz⁻¹       0.0973603 m² °⁻¹ Hz⁻¹
#  0.321368 m² °⁻¹ Hz⁻¹  0.196389 m² °⁻¹ Hz⁻¹      1.76128 m² °⁻¹ Hz⁻¹
#  0.692686 m² °⁻¹ Hz⁻¹  0.382182 m² °⁻¹ Hz⁻¹      0.00586468 m² °⁻¹ Hz⁻¹
#  0.9902 m² °⁻¹ Hz⁻¹    1.23368 m² °⁻¹ Hz⁻¹       1.32413 m² °⁻¹ Hz⁻¹
#  0.313094 m² °⁻¹ Hz⁻¹  0.282672 m² °⁻¹ Hz⁻¹   …  1.05977 m² °⁻¹ Hz⁻¹
#  1.36895 m² °⁻¹ Hz⁻¹   0.645189 m² °⁻¹ Hz⁻¹      0.828505 m² °⁻¹ Hz⁻¹
#  1.19372 m² °⁻¹ Hz⁻¹   0.70446 m² °⁻¹ Hz⁻¹       0.566231 m² °⁻¹ Hz⁻¹
#  2.16041 m² °⁻¹ Hz⁻¹   0.0915997 m² °⁻¹ Hz⁻¹     1.5018 m² °⁻¹ Hz⁻¹
#  0.333759 m² °⁻¹ Hz⁻¹  0.307477 m² °⁻¹ Hz⁻¹      1.3572 m² °⁻¹ Hz⁻¹
#  0.23816 m² °⁻¹ Hz⁻¹   0.834597 m² °⁻¹ Hz⁻¹   …  1.06276 m² °⁻¹ Hz⁻¹
#  0.609142 m² °⁻¹ Hz⁻¹  1.05432 m² °⁻¹ Hz⁻¹       0.740808 m² °⁻¹ Hz⁻¹
#  0.478071 m² °⁻¹ Hz⁻¹  0.134279 m² °⁻¹ Hz⁻¹      0.66253 m² °⁻¹ Hz⁻¹
#  0.610584 m² °⁻¹ Hz⁻¹  1.26515 m² °⁻¹ Hz⁻¹       0.042208 m² °⁻¹ Hz⁻¹
#  0.625833 m² °⁻¹ Hz⁻¹  0.0823124 m² °⁻¹ Hz⁻¹     0.160702 m² °⁻¹ Hz⁻¹

# %%
all(S .≈ S3)
# Out:
# true

# %%
integrate(S, :axis1)
# Out:
# ┌ Warning: Integration: The resulting vector is a function of direction, and is not returned as an 'OmnidirectionalSpectrum'.
# └ @ Spectra /Users/cmichel/repos/JuliaOceanWaves/WaveSpectra/src/integration.jl:21
# 36-element Vector{Quantity{Float64, 𝐋² 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, m²), 𝐋² 𝐀⁻¹, nothing}}}:
#  1.8563163863377279 m² °⁻¹
#  1.1949149532523733 m² °⁻¹
#  1.9119878974904254 m² °⁻¹
#  1.353262510380112 m² °⁻¹
#  1.4474659450315999 m² °⁻¹
#  1.5281669044522574 m² °⁻¹
#  1.4538820009968483 m² °⁻¹
#  1.9552229479330883 m² °⁻¹
#  1.4412885573385512 m² °⁻¹
#  1.2314838597688387 m² °⁻¹
#  ⋮
#  1.7974470847347495 m² °⁻¹
#  1.4804910675600007 m² °⁻¹
#  1.1918195949902626 m² °⁻¹
#  2.015519113720803 m² °⁻¹
#  1.7014455943347113 m² °⁻¹
#  1.571013942855593 m² °⁻¹
#  1.335005858987793 m² °⁻¹
#  1.548513453040419 m² °⁻¹
#  1.683488547436801 m² °⁻¹

# %%
integrate(S, Spectra.RectangularRule())
# Out:
# 578.9367791738566 m²

# %%
omni = omnidirectional_spectrum(S)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#  276.1859629482763 m² Hz⁻¹
#  325.5014223033538 m² Hz⁻¹
#  260.1721957260826 m² Hz⁻¹
#  246.95696505664543 m² Hz⁻¹
#  288.39098363721513 m² Hz⁻¹
#  306.103557807985 m² Hz⁻¹
#  299.31011894650317 m² Hz⁻¹
#  284.34989470798746 m² Hz⁻¹
#  221.09609625942718 m² Hz⁻¹
#  290.99006066467973 m² Hz⁻¹
#  272.47469581578804 m² Hz⁻¹
#  273.6720309274203 m² Hz⁻¹
#  283.29248799430695 m² Hz⁻¹
#  253.7443976452806 m² Hz⁻¹
#  309.8242334391688 m² Hz⁻¹
#  296.48385816785185 m² Hz⁻¹
#  356.54291005166107 m² Hz⁻¹
#  230.77470678138963 m² Hz⁻¹
#  271.16232545715343 m² Hz⁻¹
#  257.1284369981441 m² Hz⁻¹

# %%
omni_T = uconvert(s, :axis, omni)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓⁻¹, Unitful.FreeUnits{(m², s⁻¹), 𝐋² 𝐓⁻¹, nothing}}, Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}:
#  1028.5137479925763 m² s⁻¹
#   978.8959949003238 m² s⁻¹
#   747.7100499717025 m² s⁻¹
#  1030.4090100493004 m² s⁻¹
#   758.9986769097009 m² s⁻¹
#   697.1045252381298 m² s⁻¹
#   497.33901938474986 m² s⁻¹
#   478.76430471037884 m² s⁻¹
#   394.0877245354852 m² s⁻¹
#   329.69438193710357 m² s⁻¹
#   290.99006066467973 m² s⁻¹
#   179.08783797013604 m² s⁻¹
#   181.983932613112 m² s⁻¹
#   146.6619582837865 m² s⁻¹
#   110.1972808108746 m² s⁻¹
#    72.09774590930378 m² s⁻¹
#    39.51311440906328 m² s⁻¹
#    23.415497615347434 m² s⁻¹
#    13.020056892134155 m² s⁻¹
#     2.7618596294827635 m² s⁻¹

# %%
integrate(omni), integrate(omni_T)
# Out:
# (533.750014136311 m², 548.2343658608571 m²)

# %%
omni_m = uconvert(m, :axis, omni, deepwater)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋, Unitful.FreeUnits{(m,), 𝐋, nothing}}, Quantity{Float64, 𝐋, Unitful.FreeUnits{(m,), 𝐋, nothing}}}:
#  658.9755390086486 m
#  595.8258616136933 m
#  431.15648259206176 m
#  561.1613690177732 m
#  389.0363649097523 m
#  334.9795988343078 m
#  223.05387196440736 m
#  199.38584014142407 m
#  151.4967619242777 m
#  116.18055024353633 m
#   93.21962513720855 m
#   51.63424130593348 m
#   46.63932215537274 m
#   32.888549249112145 m
#   21.181237293531336 m
#   11.548375280501107 m
#    5.063262579901034 m
#    2.250369553981986 m
#    0.8342036287957624 m
#    0.08847708363436319 m

# %%
integrate(omni_m)
# Out:
# 571.8181143073251 m²
