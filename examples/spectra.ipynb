# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

# %%
push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ## Spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf
# Out:
# (0.0:0.1:1.9000000000000001) Hz

# %%
Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ
# Out:
# (0.0:10.0:350.0)°

# %%
S = Spectrum(randn(Nf, Nθ)*m^2/Hz/°, f, θ)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   0.986591 m² °⁻¹ Hz⁻¹     0.322135 m² °⁻¹ Hz⁻¹   …  -1.42215 m² °⁻¹ Hz⁻¹
#   0.733201 m² °⁻¹ Hz⁻¹     0.486683 m² °⁻¹ Hz⁻¹      -1.4084 m² °⁻¹ Hz⁻¹
#  -0.0255193 m² °⁻¹ Hz⁻¹    0.211305 m² °⁻¹ Hz⁻¹      -1.11084 m² °⁻¹ Hz⁻¹
#   0.571536 m² °⁻¹ Hz⁻¹     0.666102 m² °⁻¹ Hz⁻¹      -1.92258 m² °⁻¹ Hz⁻¹
#   1.12169 m² °⁻¹ Hz⁻¹      0.593616 m² °⁻¹ Hz⁻¹       0.683111 m² °⁻¹ Hz⁻¹
#   0.339386 m² °⁻¹ Hz⁻¹    -0.0493899 m² °⁻¹ Hz⁻¹  …   0.378645 m² °⁻¹ Hz⁻¹
#  -0.488024 m² °⁻¹ Hz⁻¹     2.05734 m² °⁻¹ Hz⁻¹       -0.595621 m² °⁻¹ Hz⁻¹
#  -1.43362 m² °⁻¹ Hz⁻¹     -1.14536 m² °⁻¹ Hz⁻¹       -1.37246 m² °⁻¹ Hz⁻¹
#  -0.942556 m² °⁻¹ Hz⁻¹    -0.18491 m² °⁻¹ Hz⁻¹        0.586892 m² °⁻¹ Hz⁻¹
#   0.439572 m² °⁻¹ Hz⁻¹     0.176094 m² °⁻¹ Hz⁻¹      -0.0542542 m² °⁻¹ Hz⁻¹
#  -1.35081 m² °⁻¹ Hz⁻¹      0.229892 m² °⁻¹ Hz⁻¹   …   1.56924 m² °⁻¹ Hz⁻¹
#   0.00330667 m² °⁻¹ Hz⁻¹  -0.0420561 m² °⁻¹ Hz⁻¹      1.51802 m² °⁻¹ Hz⁻¹
#  -0.0895223 m² °⁻¹ Hz⁻¹    0.233871 m² °⁻¹ Hz⁻¹      -0.517284 m² °⁻¹ Hz⁻¹
#  -0.378167 m² °⁻¹ Hz⁻¹    -0.202933 m² °⁻¹ Hz⁻¹       1.18749 m² °⁻¹ Hz⁻¹
#   0.535856 m² °⁻¹ Hz⁻¹    -1.43315 m² °⁻¹ Hz⁻¹        0.152368 m² °⁻¹ Hz⁻¹
#   0.0147031 m² °⁻¹ Hz⁻¹    0.752274 m² °⁻¹ Hz⁻¹   …  -0.122472 m² °⁻¹ Hz⁻¹
#   0.677909 m² °⁻¹ Hz⁻¹    -0.394799 m² °⁻¹ Hz⁻¹       2.75525 m² °⁻¹ Hz⁻¹
#  -0.718955 m² °⁻¹ Hz⁻¹    -0.913789 m² °⁻¹ Hz⁻¹       1.20764 m² °⁻¹ Hz⁻¹
#   0.605835 m² °⁻¹ Hz⁻¹    -0.914187 m² °⁻¹ Hz⁻¹       0.996038 m² °⁻¹ Hz⁻¹
#   0.297985 m² °⁻¹ Hz⁻¹     0.349584 m² °⁻¹ Hz⁻¹      -1.05151 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ### Basic functions & properties

# %%
propertynames(S)
# Out:
# (:data, :axis1, :axis2, :coordinates, :axestypes, :axesnames)

# %%
S.axestypes
# Out:
# (:frequency, :direction)

# %%
S.axesnames
# Out:
# (:frequency, :direction)

# %%
S.coordinates
# Out:
# :polar

# %%
unit(S)
# Out:
# m² °⁻¹ Hz⁻¹

# %%
unit(S, :spectrum), unit(S, :axis1), unit(S, :axis2), unit(S, :integral)
# Out:
# (m² °⁻¹ Hz⁻¹, Hz, °, m²)

# %%
unit(S, :frequency) # can use axis names too
# Out:
# Hz

# %%
size(S), eltype(S)
# Out:
# ((20, 36), Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}})

# %%
axesinfo(S)
# Out:
# (((:temporal, :frequency), 𝐓⁻¹), ((:direction, :angle), 𝐀))

# %%
axesinfo(S.axis1)
# Out:
# ((:temporal, :frequency), 𝐓⁻¹)

# %% [markdown]
# ### Indexing

# %%
S[2:4, 1:5]
# Out:
# 3×5 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#   0.733201 m² °⁻¹ Hz⁻¹   0.486683 m² °⁻¹ Hz⁻¹  …   0.0949987 m² °⁻¹ Hz⁻¹
#  -0.0255193 m² °⁻¹ Hz⁻¹  0.211305 m² °⁻¹ Hz⁻¹     -0.584699 m² °⁻¹ Hz⁻¹
#   0.571536 m² °⁻¹ Hz⁻¹   0.666102 m² °⁻¹ Hz⁻¹      0.524375 m² °⁻¹ Hz⁻¹

# %%
S[2, 4]
# Out:
# 0.3075824155964573 m² °⁻¹ Hz⁻¹

# %%
S[frequency=0.2Hz..0.5Hz] # if AxisArrays loaded
# Out:
# 4×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  -0.0255193 m² °⁻¹ Hz⁻¹   0.211305 m² °⁻¹ Hz⁻¹   …  -1.11084 m² °⁻¹ Hz⁻¹
#   0.571536 m² °⁻¹ Hz⁻¹    0.666102 m² °⁻¹ Hz⁻¹      -1.92258 m² °⁻¹ Hz⁻¹
#   1.12169 m² °⁻¹ Hz⁻¹     0.593616 m² °⁻¹ Hz⁻¹       0.683111 m² °⁻¹ Hz⁻¹
#   0.339386 m² °⁻¹ Hz⁻¹   -0.0493899 m² °⁻¹ Hz⁻¹      0.378645 m² °⁻¹ Hz⁻¹

# %%
S[frequency=0.1Hz..0.1Hz, direction=30°..30°]
# Out:
# 1×1 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.3075824155964573 m² °⁻¹ Hz⁻¹

# %%
S[frequency=2, direction=:]
# Out:
# 1×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.733201 m² °⁻¹ Hz⁻¹  0.486683 m² °⁻¹ Hz⁻¹  …  -1.4084 m² °⁻¹ Hz⁻¹

# %%
S[0.4Hz, 10°..30°]
# Out:
# 1×3 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.593616 m² °⁻¹ Hz⁻¹  0.345447 m² °⁻¹ Hz⁻¹  -2.62579 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ### Assignment

# %%
S2 = copy(S);

# %%
S2[2:4, 1:5] *= 100;
S2[2:4, 1:5]
# Out:
# 3×5 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#  73.3201 m² °⁻¹ Hz⁻¹   48.6683 m² °⁻¹ Hz⁻¹  …    9.49987 m² °⁻¹ Hz⁻¹
#  -2.55193 m² °⁻¹ Hz⁻¹  21.1305 m² °⁻¹ Hz⁻¹     -58.4699 m² °⁻¹ Hz⁻¹
#  57.1536 m² °⁻¹ Hz⁻¹   66.6102 m² °⁻¹ Hz⁻¹      52.4375 m² °⁻¹ Hz⁻¹

# %%
S[2:4, 1:5]
# Out:
# 3×5 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#   0.733201 m² °⁻¹ Hz⁻¹   0.486683 m² °⁻¹ Hz⁻¹  …   0.0949987 m² °⁻¹ Hz⁻¹
#  -0.0255193 m² °⁻¹ Hz⁻¹  0.211305 m² °⁻¹ Hz⁻¹     -0.584699 m² °⁻¹ Hz⁻¹
#   0.571536 m² °⁻¹ Hz⁻¹   0.666102 m² °⁻¹ Hz⁻¹      0.524375 m² °⁻¹ Hz⁻¹

# %%
S2[frequency=0.2Hz..0.2Hz, direction=10°..20°] = [99m^2/Hz/°, 99m^2/Hz/°]
# Out:
# 2-element Vector{Quantity{Int64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#  99 m² °⁻¹ Hz⁻¹
#  99 m² °⁻¹ Hz⁻¹

# %%
S2[0.2Hz, 10°..20°] = [99m^2 / Hz / °, 99m^2 / Hz / °]
# Out:
# 2-element Vector{Quantity{Int64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#  99 m² °⁻¹ Hz⁻¹
#  99 m² °⁻¹ Hz⁻¹

# %%
S2[0.2Hz, 20°] .= 100m^2/Hz/°
# Out:
# 1×1 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  100.0 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ##

# %% [markdown]
# ### Integrals

# %%
integrate(S, :axis2)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#   -92.6977317007023 m² Hz⁻¹
#    25.419287868150725 m² Hz⁻¹
#     1.3768208487214713 m² Hz⁻¹
#    15.389379847179406 m² Hz⁻¹
#    14.660847722305046 m² Hz⁻¹
#   166.445114686653 m² Hz⁻¹
#    99.04587899268354 m² Hz⁻¹
#    18.954890638761075 m² Hz⁻¹
#    40.10926681014361 m² Hz⁻¹
#    53.755203860929235 m² Hz⁻¹
#     9.074433120299561 m² Hz⁻¹
#   -40.805269457966915 m² Hz⁻¹
#   -16.012606407916525 m² Hz⁻¹
#  -100.24618885691827 m² Hz⁻¹
#    23.709016075528098 m² Hz⁻¹
#    -6.91825218248544 m² Hz⁻¹
#   -23.667629146720955 m² Hz⁻¹
#   -54.86607191519934 m² Hz⁻¹
#   -30.394219846394478 m² Hz⁻¹
#   -96.07629144468183 m² Hz⁻¹

# %%
omni = integrate(S, :direction)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#   -92.6977317007023 m² Hz⁻¹
#    25.419287868150725 m² Hz⁻¹
#     1.3768208487214713 m² Hz⁻¹
#    15.389379847179406 m² Hz⁻¹
#    14.660847722305046 m² Hz⁻¹
#   166.445114686653 m² Hz⁻¹
#    99.04587899268354 m² Hz⁻¹
#    18.954890638761075 m² Hz⁻¹
#    40.10926681014361 m² Hz⁻¹
#    53.755203860929235 m² Hz⁻¹
#     9.074433120299561 m² Hz⁻¹
#   -40.805269457966915 m² Hz⁻¹
#   -16.012606407916525 m² Hz⁻¹
#  -100.24618885691827 m² Hz⁻¹
#    23.709016075528098 m² Hz⁻¹
#    -6.91825218248544 m² Hz⁻¹
#   -23.667629146720955 m² Hz⁻¹
#   -54.86607191519934 m² Hz⁻¹
#   -30.394219846394478 m² Hz⁻¹
#   -96.07629144468183 m² Hz⁻¹

# %%
integrate(S, :frequency)
# Out:
# ┌ Warning: Integration: The resulting vector is a function of direction, and is not returned as an 'OmnidirectionalSpectrum'.
# └ @ Spectra /Users/cmichel/repos/JuliaOceanWaves/WaveSpectra/src/integration.jl:21
# 36-element Vector{Quantity{Float64, 𝐋² 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, m²), 𝐋² 𝐀⁻¹, nothing}}}:
#   0.02581021981309624 m² °⁻¹
#   0.046245857639293994 m² °⁻¹
#  -0.29716834025547695 m² °⁻¹
#  -0.27464097424638734 m² °⁻¹
#   0.08843870522670769 m² °⁻¹
#   0.7908083291158199 m² °⁻¹
#   0.4686417536863764 m² °⁻¹
#   0.8031800403729914 m² °⁻¹
#   0.7597186439388621 m² °⁻¹
#  -0.2675745924145725 m² °⁻¹
#   ⋮
#   0.1362674954500075 m² °⁻¹
#  -0.0039628126550228585 m² °⁻¹
#   0.5509523645460005 m² °⁻¹
#  -0.02230215978590307 m² °⁻¹
#  -0.24877925228147008 m² °⁻¹
#  -0.6693659051864927 m² °⁻¹
#   0.32847982843217144 m² °⁻¹
#   0.3262719947070871 m² °⁻¹
#   0.2693940524899938 m² °⁻¹

# %%
integrate(S)
# Out:
# 10.064289108506088 m²

# %% [markdown]
# ### Random

# %%
SC = Spectrum((randn(Nf, Nθ) + randn(Nf, Nθ)*im)*m^2/Hz/°, f, θ)
# Out:
# 20×36 Spectrum{Quantity{ComplexF64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   (0.753914+0.878941im) m² °⁻¹ Hz⁻¹   …   (0.0590968-0.535777im) m² °⁻¹ Hz⁻¹
#  (-0.472366-1.4886im) m² °⁻¹ Hz⁻¹           (0.76042-0.511694im) m² °⁻¹ Hz⁻¹
#   (-2.31928-0.70669im) m² °⁻¹ Hz⁻¹          (1.04798-3.19819im) m² °⁻¹ Hz⁻¹
#   (0.225563-0.26735im) m² °⁻¹ Hz⁻¹        (-0.404666-0.133567im) m² °⁻¹ Hz⁻¹
#    (1.38864-1.67295im) m² °⁻¹ Hz⁻¹        (-0.314441+0.285325im) m² °⁻¹ Hz⁻¹
#  (-0.877155-0.0956033im) m² °⁻¹ Hz⁻¹  …    (0.611562+0.4034im) m² °⁻¹ Hz⁻¹
#  (-0.595189-1.73642im) m² °⁻¹ Hz⁻¹          (-0.1632+1.33154im) m² °⁻¹ Hz⁻¹
#   (-1.66093-0.512201im) m² °⁻¹ Hz⁻¹        (0.328846-1.29524im) m² °⁻¹ Hz⁻¹
#     (1.6909+2.0248im) m² °⁻¹ Hz⁻¹         (-0.952919-1.63169im) m² °⁻¹ Hz⁻¹
#   (0.184002-0.0815856im) m² °⁻¹ Hz⁻¹       (-0.43437-0.242926im) m² °⁻¹ Hz⁻¹
#   (0.669784+0.536554im) m² °⁻¹ Hz⁻¹   …    (0.577799+0.48817im) m² °⁻¹ Hz⁻¹
#  (-0.368473-0.399593im) m² °⁻¹ Hz⁻¹        (0.120494+0.0396326im) m² °⁻¹ Hz⁻¹
#  (0.0707619+1.18036im) m² °⁻¹ Hz⁻¹        (-0.045937-1.44782im) m² °⁻¹ Hz⁻¹
#   (-1.81169-0.33881im) m² °⁻¹ Hz⁻¹       (-0.0880653-0.128669im) m² °⁻¹ Hz⁻¹
#  (-0.774466-0.399638im) m² °⁻¹ Hz⁻¹         (2.12944-0.315358im) m² °⁻¹ Hz⁻¹
#    (1.06588+0.0931909im) m² °⁻¹ Hz⁻¹  …    (-1.19309+1.71227im) m² °⁻¹ Hz⁻¹
#    (2.22831+0.294012im) m² °⁻¹ Hz⁻¹        (0.272314-0.18389im) m² °⁻¹ Hz⁻¹
#  (-0.632327+1.96556im) m² °⁻¹ Hz⁻¹         (0.838097-0.567493im) m² °⁻¹ Hz⁻¹
#    (2.87677-0.736837im) m² °⁻¹ Hz⁻¹      (-0.0791281-0.219585im) m² °⁻¹ Hz⁻¹
#  (-0.760392-0.734898im) m² °⁻¹ Hz⁻¹        (0.508457-0.396915im) m² °⁻¹ Hz⁻¹

# %%
abs.(SC)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  1.15798 m² °⁻¹ Hz⁻¹   1.54922 m² °⁻¹ Hz⁻¹   …  0.539026 m² °⁻¹ Hz⁻¹
#  1.56175 m² °⁻¹ Hz⁻¹   0.920409 m² °⁻¹ Hz⁻¹     0.916553 m² °⁻¹ Hz⁻¹
#  2.42455 m² °⁻¹ Hz⁻¹   2.25477 m² °⁻¹ Hz⁻¹      3.36551 m² °⁻¹ Hz⁻¹
#  0.349792 m² °⁻¹ Hz⁻¹  0.833886 m² °⁻¹ Hz⁻¹     0.42614 m² °⁻¹ Hz⁻¹
#  2.17418 m² °⁻¹ Hz⁻¹   1.14534 m² °⁻¹ Hz⁻¹      0.424598 m² °⁻¹ Hz⁻¹
#  0.882349 m² °⁻¹ Hz⁻¹  1.36408 m² °⁻¹ Hz⁻¹   …  0.732625 m² °⁻¹ Hz⁻¹
#  1.8356 m² °⁻¹ Hz⁻¹    1.58212 m² °⁻¹ Hz⁻¹      1.3415 m² °⁻¹ Hz⁻¹
#  1.73812 m² °⁻¹ Hz⁻¹   1.82228 m² °⁻¹ Hz⁻¹      1.33633 m² °⁻¹ Hz⁻¹
#  2.63798 m² °⁻¹ Hz⁻¹   0.739518 m² °⁻¹ Hz⁻¹     1.88956 m² °⁻¹ Hz⁻¹
#  0.201278 m² °⁻¹ Hz⁻¹  1.46642 m² °⁻¹ Hz⁻¹      0.497684 m² °⁻¹ Hz⁻¹
#  0.858197 m² °⁻¹ Hz⁻¹  0.333011 m² °⁻¹ Hz⁻¹  …  0.756414 m² °⁻¹ Hz⁻¹
#  0.54355 m² °⁻¹ Hz⁻¹   0.759545 m² °⁻¹ Hz⁻¹     0.126844 m² °⁻¹ Hz⁻¹
#  1.18248 m² °⁻¹ Hz⁻¹   1.01689 m² °⁻¹ Hz⁻¹      1.44855 m² °⁻¹ Hz⁻¹
#  1.8431 m² °⁻¹ Hz⁻¹    1.47335 m² °⁻¹ Hz⁻¹      0.155921 m² °⁻¹ Hz⁻¹
#  0.871498 m² °⁻¹ Hz⁻¹  1.44505 m² °⁻¹ Hz⁻¹      2.15267 m² °⁻¹ Hz⁻¹
#  1.06995 m² °⁻¹ Hz⁻¹   1.78304 m² °⁻¹ Hz⁻¹   …  2.08694 m² °⁻¹ Hz⁻¹
#  2.24762 m² °⁻¹ Hz⁻¹   1.1866 m² °⁻¹ Hz⁻¹       0.328589 m² °⁻¹ Hz⁻¹
#  2.06477 m² °⁻¹ Hz⁻¹   2.4136 m² °⁻¹ Hz⁻¹       1.01215 m² °⁻¹ Hz⁻¹
#  2.96963 m² °⁻¹ Hz⁻¹   0.605551 m² °⁻¹ Hz⁻¹     0.233407 m² °⁻¹ Hz⁻¹
#  1.05748 m² °⁻¹ Hz⁻¹   1.38704 m² °⁻¹ Hz⁻¹      0.645035 m² °⁻¹ Hz⁻¹

# %%
angle.(°, SC)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#    49.3786°   -145.253°     148.717°    …  159.272°     -83.7057°
#  -107.605°     -79.1503°     29.337°        35.7616°    -33.937°
#  -163.054°     133.463°      20.7179°      -54.2417°    -71.8571°
#   -49.8456°    156.695°     -66.8164°      -36.6302°   -161.734°
#   -50.3055°   -142.608°     166.942°         9.41546°   137.779°
#  -173.78°      144.796°     116.091°    …   57.7171°     33.4097°
#  -108.92°      138.679°     178.251°        -8.04001°    96.9876°
#  -162.861°     -46.3101°     35.7785°      -99.742°     -75.7543°
#    50.1349°    156.918°       8.41153°     157.107°    -120.285°
#   -23.9123°    -94.2362°     29.7178°       22.151°    -150.783°
#    38.6977°    -64.1945°   -133.969°    …   72.5623°     40.1937°
#  -132.68°      129.721°      73.0891°      -59.1058°     18.207°
#    86.5693°    173.102°     172.746°       131.78°      -91.8173°
#  -169.407°      -9.20002°  -118.59°        -32.5371°   -124.389°
#  -152.705°     -77.5097°     86.3701°      -73.8818°     -8.42393°
#     4.99672°   -91.2874°      6.88529°  …  -73.6013°    124.868°
#     7.51643°   -22.5461°   -120.718°         6.18048°   -34.0307°
#   107.833°     159.44°       54.9652°       65.2342°    -34.1028°
#   -14.3665°    -85.9069°    -81.4522°       23.718°    -109.817°
#  -135.977°     109.785°     -11.7685°       34.8237°    -37.9765°

# %%
S + S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   1.97318 m² °⁻¹ Hz⁻¹      0.64427 m² °⁻¹ Hz⁻¹    …  -2.84429 m² °⁻¹ Hz⁻¹
#   1.4664 m² °⁻¹ Hz⁻¹       0.973367 m² °⁻¹ Hz⁻¹      -2.81681 m² °⁻¹ Hz⁻¹
#  -0.0510387 m² °⁻¹ Hz⁻¹    0.42261 m² °⁻¹ Hz⁻¹       -2.22168 m² °⁻¹ Hz⁻¹
#   1.14307 m² °⁻¹ Hz⁻¹      1.3322 m² °⁻¹ Hz⁻¹        -3.84516 m² °⁻¹ Hz⁻¹
#   2.24337 m² °⁻¹ Hz⁻¹      1.18723 m² °⁻¹ Hz⁻¹        1.36622 m² °⁻¹ Hz⁻¹
#   0.678773 m² °⁻¹ Hz⁻¹    -0.0987799 m² °⁻¹ Hz⁻¹  …   0.757289 m² °⁻¹ Hz⁻¹
#  -0.976048 m² °⁻¹ Hz⁻¹     4.11468 m² °⁻¹ Hz⁻¹       -1.19124 m² °⁻¹ Hz⁻¹
#  -2.86725 m² °⁻¹ Hz⁻¹     -2.29072 m² °⁻¹ Hz⁻¹       -2.74492 m² °⁻¹ Hz⁻¹
#  -1.88511 m² °⁻¹ Hz⁻¹     -0.36982 m² °⁻¹ Hz⁻¹        1.17378 m² °⁻¹ Hz⁻¹
#   0.879144 m² °⁻¹ Hz⁻¹     0.352188 m² °⁻¹ Hz⁻¹      -0.108508 m² °⁻¹ Hz⁻¹
#  -2.70162 m² °⁻¹ Hz⁻¹      0.459783 m² °⁻¹ Hz⁻¹   …   3.13848 m² °⁻¹ Hz⁻¹
#   0.00661333 m² °⁻¹ Hz⁻¹  -0.0841122 m² °⁻¹ Hz⁻¹      3.03604 m² °⁻¹ Hz⁻¹
#  -0.179045 m² °⁻¹ Hz⁻¹     0.467741 m² °⁻¹ Hz⁻¹      -1.03457 m² °⁻¹ Hz⁻¹
#  -0.756333 m² °⁻¹ Hz⁻¹    -0.405866 m² °⁻¹ Hz⁻¹       2.37497 m² °⁻¹ Hz⁻¹
#   1.07171 m² °⁻¹ Hz⁻¹     -2.8663 m² °⁻¹ Hz⁻¹         0.304736 m² °⁻¹ Hz⁻¹
#   0.0294061 m² °⁻¹ Hz⁻¹    1.50455 m² °⁻¹ Hz⁻¹    …  -0.244944 m² °⁻¹ Hz⁻¹
#   1.35582 m² °⁻¹ Hz⁻¹     -0.789599 m² °⁻¹ Hz⁻¹       5.5105 m² °⁻¹ Hz⁻¹
#  -1.43791 m² °⁻¹ Hz⁻¹     -1.82758 m² °⁻¹ Hz⁻¹        2.41527 m² °⁻¹ Hz⁻¹
#   1.21167 m² °⁻¹ Hz⁻¹     -1.82837 m² °⁻¹ Hz⁻¹        1.99208 m² °⁻¹ Hz⁻¹
#   0.595971 m² °⁻¹ Hz⁻¹     0.699168 m² °⁻¹ Hz⁻¹      -2.10301 m² °⁻¹ Hz⁻¹

# %%
2S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   1.97318 m² °⁻¹ Hz⁻¹      0.64427 m² °⁻¹ Hz⁻¹    …  -2.84429 m² °⁻¹ Hz⁻¹
#   1.4664 m² °⁻¹ Hz⁻¹       0.973367 m² °⁻¹ Hz⁻¹      -2.81681 m² °⁻¹ Hz⁻¹
#  -0.0510387 m² °⁻¹ Hz⁻¹    0.42261 m² °⁻¹ Hz⁻¹       -2.22168 m² °⁻¹ Hz⁻¹
#   1.14307 m² °⁻¹ Hz⁻¹      1.3322 m² °⁻¹ Hz⁻¹        -3.84516 m² °⁻¹ Hz⁻¹
#   2.24337 m² °⁻¹ Hz⁻¹      1.18723 m² °⁻¹ Hz⁻¹        1.36622 m² °⁻¹ Hz⁻¹
#   0.678773 m² °⁻¹ Hz⁻¹    -0.0987799 m² °⁻¹ Hz⁻¹  …   0.757289 m² °⁻¹ Hz⁻¹
#  -0.976048 m² °⁻¹ Hz⁻¹     4.11468 m² °⁻¹ Hz⁻¹       -1.19124 m² °⁻¹ Hz⁻¹
#  -2.86725 m² °⁻¹ Hz⁻¹     -2.29072 m² °⁻¹ Hz⁻¹       -2.74492 m² °⁻¹ Hz⁻¹
#  -1.88511 m² °⁻¹ Hz⁻¹     -0.36982 m² °⁻¹ Hz⁻¹        1.17378 m² °⁻¹ Hz⁻¹
#   0.879144 m² °⁻¹ Hz⁻¹     0.352188 m² °⁻¹ Hz⁻¹      -0.108508 m² °⁻¹ Hz⁻¹
#  -2.70162 m² °⁻¹ Hz⁻¹      0.459783 m² °⁻¹ Hz⁻¹   …   3.13848 m² °⁻¹ Hz⁻¹
#   0.00661333 m² °⁻¹ Hz⁻¹  -0.0841122 m² °⁻¹ Hz⁻¹      3.03604 m² °⁻¹ Hz⁻¹
#  -0.179045 m² °⁻¹ Hz⁻¹     0.467741 m² °⁻¹ Hz⁻¹      -1.03457 m² °⁻¹ Hz⁻¹
#  -0.756333 m² °⁻¹ Hz⁻¹    -0.405866 m² °⁻¹ Hz⁻¹       2.37497 m² °⁻¹ Hz⁻¹
#   1.07171 m² °⁻¹ Hz⁻¹     -2.8663 m² °⁻¹ Hz⁻¹         0.304736 m² °⁻¹ Hz⁻¹
#   0.0294061 m² °⁻¹ Hz⁻¹    1.50455 m² °⁻¹ Hz⁻¹    …  -0.244944 m² °⁻¹ Hz⁻¹
#   1.35582 m² °⁻¹ Hz⁻¹     -0.789599 m² °⁻¹ Hz⁻¹       5.5105 m² °⁻¹ Hz⁻¹
#  -1.43791 m² °⁻¹ Hz⁻¹     -1.82758 m² °⁻¹ Hz⁻¹        2.41527 m² °⁻¹ Hz⁻¹
#   1.21167 m² °⁻¹ Hz⁻¹     -1.82837 m² °⁻¹ Hz⁻¹        1.99208 m² °⁻¹ Hz⁻¹
#   0.595971 m² °⁻¹ Hz⁻¹     0.699168 m² °⁻¹ Hz⁻¹      -2.10301 m² °⁻¹ Hz⁻¹

# %%
try
    S .+ Spectrum(S.data, 2f, θ)
catch
    println("catch")
end
# Out:
# catch

# %% [markdown]
# ### Convert: units

# %%
S3 = Spectrum(randn(Nf, Nθ)m^2/Hz/°, collect(2f), collect(θ))
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#   1.28756 m² °⁻¹ Hz⁻¹    0.986942 m² °⁻¹ Hz⁻¹    …  -1.47659 m² °⁻¹ Hz⁻¹
#  -1.10189 m² °⁻¹ Hz⁻¹   -0.648723 m² °⁻¹ Hz⁻¹        0.234204 m² °⁻¹ Hz⁻¹
#  -0.86921 m² °⁻¹ Hz⁻¹    0.0576076 m² °⁻¹ Hz⁻¹       0.164043 m² °⁻¹ Hz⁻¹
#   1.57542 m² °⁻¹ Hz⁻¹    0.530248 m² °⁻¹ Hz⁻¹       -0.883607 m² °⁻¹ Hz⁻¹
#  -1.244 m² °⁻¹ Hz⁻¹     -0.901263 m² °⁻¹ Hz⁻¹        1.67963 m² °⁻¹ Hz⁻¹
#  -1.55274 m² °⁻¹ Hz⁻¹    0.347437 m² °⁻¹ Hz⁻¹    …   0.0834058 m² °⁻¹ Hz⁻¹
#   0.696094 m² °⁻¹ Hz⁻¹   0.0082404 m² °⁻¹ Hz⁻¹      -0.484431 m² °⁻¹ Hz⁻¹
#  -0.518394 m² °⁻¹ Hz⁻¹   1.53048 m² °⁻¹ Hz⁻¹        -1.39638 m² °⁻¹ Hz⁻¹
#  -1.52649 m² °⁻¹ Hz⁻¹   -0.00446299 m² °⁻¹ Hz⁻¹      0.164333 m² °⁻¹ Hz⁻¹
#  -0.226093 m² °⁻¹ Hz⁻¹  -0.206888 m² °⁻¹ Hz⁻¹        0.794646 m² °⁻¹ Hz⁻¹
#   0.371709 m² °⁻¹ Hz⁻¹   0.797658 m² °⁻¹ Hz⁻¹    …  -0.199748 m² °⁻¹ Hz⁻¹
#  -2.4231 m² °⁻¹ Hz⁻¹     1.71486 m² °⁻¹ Hz⁻¹        -0.752443 m² °⁻¹ Hz⁻¹
#  -1.3585 m² °⁻¹ Hz⁻¹    -0.843729 m² °⁻¹ Hz⁻¹       -1.82188 m² °⁻¹ Hz⁻¹
#   1.30228 m² °⁻¹ Hz⁻¹   -0.362219 m² °⁻¹ Hz⁻¹        0.853177 m² °⁻¹ Hz⁻¹
#  -0.680164 m² °⁻¹ Hz⁻¹  -0.86161 m² °⁻¹ Hz⁻¹         0.185731 m² °⁻¹ Hz⁻¹
#   0.559188 m² °⁻¹ Hz⁻¹   0.915892 m² °⁻¹ Hz⁻¹    …   0.289252 m² °⁻¹ Hz⁻¹
#  -0.889976 m² °⁻¹ Hz⁻¹   1.39815 m² °⁻¹ Hz⁻¹         0.190977 m² °⁻¹ Hz⁻¹
#   0.391731 m² °⁻¹ Hz⁻¹  -0.493406 m² °⁻¹ Hz⁻¹       -0.525023 m² °⁻¹ Hz⁻¹
#  -0.413171 m² °⁻¹ Hz⁻¹  -0.430841 m² °⁻¹ Hz⁻¹        1.00033 m² °⁻¹ Hz⁻¹
#  -1.30234 m² °⁻¹ Hz⁻¹   -1.11814 m² °⁻¹ Hz⁻¹         2.09277 m² °⁻¹ Hz⁻¹

# %%
S3[1,1] = 1.2km^2/°/Hz;
S3
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#   1.2e6 m² °⁻¹ Hz⁻¹      0.986942 m² °⁻¹ Hz⁻¹    …  -1.47659 m² °⁻¹ Hz⁻¹
#  -1.10189 m² °⁻¹ Hz⁻¹   -0.648723 m² °⁻¹ Hz⁻¹        0.234204 m² °⁻¹ Hz⁻¹
#  -0.86921 m² °⁻¹ Hz⁻¹    0.0576076 m² °⁻¹ Hz⁻¹       0.164043 m² °⁻¹ Hz⁻¹
#   1.57542 m² °⁻¹ Hz⁻¹    0.530248 m² °⁻¹ Hz⁻¹       -0.883607 m² °⁻¹ Hz⁻¹
#  -1.244 m² °⁻¹ Hz⁻¹     -0.901263 m² °⁻¹ Hz⁻¹        1.67963 m² °⁻¹ Hz⁻¹
#  -1.55274 m² °⁻¹ Hz⁻¹    0.347437 m² °⁻¹ Hz⁻¹    …   0.0834058 m² °⁻¹ Hz⁻¹
#   0.696094 m² °⁻¹ Hz⁻¹   0.0082404 m² °⁻¹ Hz⁻¹      -0.484431 m² °⁻¹ Hz⁻¹
#  -0.518394 m² °⁻¹ Hz⁻¹   1.53048 m² °⁻¹ Hz⁻¹        -1.39638 m² °⁻¹ Hz⁻¹
#  -1.52649 m² °⁻¹ Hz⁻¹   -0.00446299 m² °⁻¹ Hz⁻¹      0.164333 m² °⁻¹ Hz⁻¹
#  -0.226093 m² °⁻¹ Hz⁻¹  -0.206888 m² °⁻¹ Hz⁻¹        0.794646 m² °⁻¹ Hz⁻¹
#   0.371709 m² °⁻¹ Hz⁻¹   0.797658 m² °⁻¹ Hz⁻¹    …  -0.199748 m² °⁻¹ Hz⁻¹
#  -2.4231 m² °⁻¹ Hz⁻¹     1.71486 m² °⁻¹ Hz⁻¹        -0.752443 m² °⁻¹ Hz⁻¹
#  -1.3585 m² °⁻¹ Hz⁻¹    -0.843729 m² °⁻¹ Hz⁻¹       -1.82188 m² °⁻¹ Hz⁻¹
#   1.30228 m² °⁻¹ Hz⁻¹   -0.362219 m² °⁻¹ Hz⁻¹        0.853177 m² °⁻¹ Hz⁻¹
#  -0.680164 m² °⁻¹ Hz⁻¹  -0.86161 m² °⁻¹ Hz⁻¹         0.185731 m² °⁻¹ Hz⁻¹
#   0.559188 m² °⁻¹ Hz⁻¹   0.915892 m² °⁻¹ Hz⁻¹    …   0.289252 m² °⁻¹ Hz⁻¹
#  -0.889976 m² °⁻¹ Hz⁻¹   1.39815 m² °⁻¹ Hz⁻¹         0.190977 m² °⁻¹ Hz⁻¹
#   0.391731 m² °⁻¹ Hz⁻¹  -0.493406 m² °⁻¹ Hz⁻¹       -0.525023 m² °⁻¹ Hz⁻¹
#  -0.413171 m² °⁻¹ Hz⁻¹  -0.430841 m² °⁻¹ Hz⁻¹        1.00033 m² °⁻¹ Hz⁻¹
#  -1.30234 m² °⁻¹ Hz⁻¹   -1.11814 m² °⁻¹ Hz⁻¹         2.09277 m² °⁻¹ Hz⁻¹

# %%
uconvert.(km^2/Hz/°, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   9.86591e-7 km² °⁻¹ Hz⁻¹  …  -1.42215e-6 km² °⁻¹ Hz⁻¹
#   7.33201e-7 km² °⁻¹ Hz⁻¹     -1.4084e-6 km² °⁻¹ Hz⁻¹
#  -2.55193e-8 km² °⁻¹ Hz⁻¹     -1.11084e-6 km² °⁻¹ Hz⁻¹
#   5.71536e-7 km² °⁻¹ Hz⁻¹     -1.92258e-6 km² °⁻¹ Hz⁻¹
#   1.12169e-6 km² °⁻¹ Hz⁻¹      6.83111e-7 km² °⁻¹ Hz⁻¹
#   3.39386e-7 km² °⁻¹ Hz⁻¹  …   3.78645e-7 km² °⁻¹ Hz⁻¹
#  -4.88024e-7 km² °⁻¹ Hz⁻¹     -5.95621e-7 km² °⁻¹ Hz⁻¹
#  -1.43362e-6 km² °⁻¹ Hz⁻¹     -1.37246e-6 km² °⁻¹ Hz⁻¹
#  -9.42556e-7 km² °⁻¹ Hz⁻¹      5.86892e-7 km² °⁻¹ Hz⁻¹
#   4.39572e-7 km² °⁻¹ Hz⁻¹     -5.42542e-8 km² °⁻¹ Hz⁻¹
#  -1.35081e-6 km² °⁻¹ Hz⁻¹  …   1.56924e-6 km² °⁻¹ Hz⁻¹
#   3.30667e-9 km² °⁻¹ Hz⁻¹      1.51802e-6 km² °⁻¹ Hz⁻¹
#  -8.95223e-8 km² °⁻¹ Hz⁻¹     -5.17284e-7 km² °⁻¹ Hz⁻¹
#  -3.78167e-7 km² °⁻¹ Hz⁻¹      1.18749e-6 km² °⁻¹ Hz⁻¹
#   5.35856e-7 km² °⁻¹ Hz⁻¹      1.52368e-7 km² °⁻¹ Hz⁻¹
#   1.47031e-8 km² °⁻¹ Hz⁻¹  …  -1.22472e-7 km² °⁻¹ Hz⁻¹
#   6.77909e-7 km² °⁻¹ Hz⁻¹      2.75525e-6 km² °⁻¹ Hz⁻¹
#  -7.18955e-7 km² °⁻¹ Hz⁻¹      1.20764e-6 km² °⁻¹ Hz⁻¹
#   6.05835e-7 km² °⁻¹ Hz⁻¹      9.96038e-7 km² °⁻¹ Hz⁻¹
#   2.97985e-7 km² °⁻¹ Hz⁻¹     -1.05151e-6 km² °⁻¹ Hz⁻¹

# %%
SB = Spectrum(randn(Nf, Nθ)m^2 / Hz / °, collect(2f), collect(θ).|>rad)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(rad,), 𝐀, nothing}}}}:
#   0.0241806 m² °⁻¹ Hz⁻¹  -1.52456 m² °⁻¹ Hz⁻¹    …   1.29654 m² °⁻¹ Hz⁻¹
#  -0.105812 m² °⁻¹ Hz⁻¹   -1.05431 m² °⁻¹ Hz⁻¹       -1.82754 m² °⁻¹ Hz⁻¹
#   0.434303 m² °⁻¹ Hz⁻¹   -0.209764 m² °⁻¹ Hz⁻¹       0.494704 m² °⁻¹ Hz⁻¹
#   0.649348 m² °⁻¹ Hz⁻¹   -0.778877 m² °⁻¹ Hz⁻¹       0.382034 m² °⁻¹ Hz⁻¹
#   0.0543911 m² °⁻¹ Hz⁻¹   0.244083 m² °⁻¹ Hz⁻¹      -0.932283 m² °⁻¹ Hz⁻¹
#  -0.599427 m² °⁻¹ Hz⁻¹    0.123571 m² °⁻¹ Hz⁻¹   …  -0.615681 m² °⁻¹ Hz⁻¹
#   2.33697 m² °⁻¹ Hz⁻¹     1.01973 m² °⁻¹ Hz⁻¹        0.819741 m² °⁻¹ Hz⁻¹
#  -0.15288 m² °⁻¹ Hz⁻¹     1.43812 m² °⁻¹ Hz⁻¹       -0.964508 m² °⁻¹ Hz⁻¹
#   0.994274 m² °⁻¹ Hz⁻¹   -0.610866 m² °⁻¹ Hz⁻¹       0.587744 m² °⁻¹ Hz⁻¹
#   0.317151 m² °⁻¹ Hz⁻¹   -1.32058 m² °⁻¹ Hz⁻¹        2.85171 m² °⁻¹ Hz⁻¹
#  -0.489522 m² °⁻¹ Hz⁻¹   -1.90442 m² °⁻¹ Hz⁻¹    …  -2.11073 m² °⁻¹ Hz⁻¹
#   0.105332 m² °⁻¹ Hz⁻¹   -2.34042 m² °⁻¹ Hz⁻¹       -0.0662828 m² °⁻¹ Hz⁻¹
#   0.126471 m² °⁻¹ Hz⁻¹   -1.37583 m² °⁻¹ Hz⁻¹        0.31605 m² °⁻¹ Hz⁻¹
#   3.02984 m² °⁻¹ Hz⁻¹    -1.23855 m² °⁻¹ Hz⁻¹       -0.55698 m² °⁻¹ Hz⁻¹
#   0.925765 m² °⁻¹ Hz⁻¹    1.045 m² °⁻¹ Hz⁻¹         -0.616976 m² °⁻¹ Hz⁻¹
#  -0.328903 m² °⁻¹ Hz⁻¹   -1.51127 m² °⁻¹ Hz⁻¹    …  -0.180788 m² °⁻¹ Hz⁻¹
#   1.66232 m² °⁻¹ Hz⁻¹     0.0810504 m² °⁻¹ Hz⁻¹     -0.492013 m² °⁻¹ Hz⁻¹
#   0.066212 m² °⁻¹ Hz⁻¹    0.0822167 m² °⁻¹ Hz⁻¹     -0.489611 m² °⁻¹ Hz⁻¹
#  -0.518923 m² °⁻¹ Hz⁻¹   -2.0667 m² °⁻¹ Hz⁻¹         0.250301 m² °⁻¹ Hz⁻¹
#   0.332478 m² °⁻¹ Hz⁻¹    1.22529 m² °⁻¹ Hz⁻¹       -1.94241 m² °⁻¹ Hz⁻¹

# %%
integrate(SB)
# Out:
# -0.5032265204729238 m² rad °⁻¹

# %%
upreferred(integrate(SB))
# Out:
# -28.83275576215225 m²

# %% [markdown]
# ### Convert: Quantities

# %%
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   0.986591 m² °⁻¹ Hz⁻¹     0.322135 m² °⁻¹ Hz⁻¹   …  -1.42215 m² °⁻¹ Hz⁻¹
#   0.733201 m² °⁻¹ Hz⁻¹     0.486683 m² °⁻¹ Hz⁻¹      -1.4084 m² °⁻¹ Hz⁻¹
#  -0.0255193 m² °⁻¹ Hz⁻¹    0.211305 m² °⁻¹ Hz⁻¹      -1.11084 m² °⁻¹ Hz⁻¹
#   0.571536 m² °⁻¹ Hz⁻¹     0.666102 m² °⁻¹ Hz⁻¹      -1.92258 m² °⁻¹ Hz⁻¹
#   1.12169 m² °⁻¹ Hz⁻¹      0.593616 m² °⁻¹ Hz⁻¹       0.683111 m² °⁻¹ Hz⁻¹
#   0.339386 m² °⁻¹ Hz⁻¹    -0.0493899 m² °⁻¹ Hz⁻¹  …   0.378645 m² °⁻¹ Hz⁻¹
#  -0.488024 m² °⁻¹ Hz⁻¹     2.05734 m² °⁻¹ Hz⁻¹       -0.595621 m² °⁻¹ Hz⁻¹
#  -1.43362 m² °⁻¹ Hz⁻¹     -1.14536 m² °⁻¹ Hz⁻¹       -1.37246 m² °⁻¹ Hz⁻¹
#  -0.942556 m² °⁻¹ Hz⁻¹    -0.18491 m² °⁻¹ Hz⁻¹        0.586892 m² °⁻¹ Hz⁻¹
#   0.439572 m² °⁻¹ Hz⁻¹     0.176094 m² °⁻¹ Hz⁻¹      -0.0542542 m² °⁻¹ Hz⁻¹
#  -1.35081 m² °⁻¹ Hz⁻¹      0.229892 m² °⁻¹ Hz⁻¹   …   1.56924 m² °⁻¹ Hz⁻¹
#   0.00330667 m² °⁻¹ Hz⁻¹  -0.0420561 m² °⁻¹ Hz⁻¹      1.51802 m² °⁻¹ Hz⁻¹
#  -0.0895223 m² °⁻¹ Hz⁻¹    0.233871 m² °⁻¹ Hz⁻¹      -0.517284 m² °⁻¹ Hz⁻¹
#  -0.378167 m² °⁻¹ Hz⁻¹    -0.202933 m² °⁻¹ Hz⁻¹       1.18749 m² °⁻¹ Hz⁻¹
#   0.535856 m² °⁻¹ Hz⁻¹    -1.43315 m² °⁻¹ Hz⁻¹        0.152368 m² °⁻¹ Hz⁻¹
#   0.0147031 m² °⁻¹ Hz⁻¹    0.752274 m² °⁻¹ Hz⁻¹   …  -0.122472 m² °⁻¹ Hz⁻¹
#   0.677909 m² °⁻¹ Hz⁻¹    -0.394799 m² °⁻¹ Hz⁻¹       2.75525 m² °⁻¹ Hz⁻¹
#  -0.718955 m² °⁻¹ Hz⁻¹    -0.913789 m² °⁻¹ Hz⁻¹       1.20764 m² °⁻¹ Hz⁻¹
#   0.605835 m² °⁻¹ Hz⁻¹    -0.914187 m² °⁻¹ Hz⁻¹       0.996038 m² °⁻¹ Hz⁻¹
#   0.297985 m² °⁻¹ Hz⁻¹     0.349584 m² °⁻¹ Hz⁻¹      -1.05151 m² °⁻¹ Hz⁻¹

# %%
disp = Dispersion()
# Out:
# Dispersion(nothing, nothing)

# %%
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#   0.986591 m² °⁻¹ Hz⁻¹     0.322135 m² °⁻¹ Hz⁻¹   …  -1.42215 m² °⁻¹ Hz⁻¹
#   0.733201 m² °⁻¹ Hz⁻¹     0.486683 m² °⁻¹ Hz⁻¹      -1.4084 m² °⁻¹ Hz⁻¹
#  -0.0255193 m² °⁻¹ Hz⁻¹    0.211305 m² °⁻¹ Hz⁻¹      -1.11084 m² °⁻¹ Hz⁻¹
#   0.571536 m² °⁻¹ Hz⁻¹     0.666102 m² °⁻¹ Hz⁻¹      -1.92258 m² °⁻¹ Hz⁻¹
#   1.12169 m² °⁻¹ Hz⁻¹      0.593616 m² °⁻¹ Hz⁻¹       0.683111 m² °⁻¹ Hz⁻¹
#   0.339386 m² °⁻¹ Hz⁻¹    -0.0493899 m² °⁻¹ Hz⁻¹  …   0.378645 m² °⁻¹ Hz⁻¹
#  -0.488024 m² °⁻¹ Hz⁻¹     2.05734 m² °⁻¹ Hz⁻¹       -0.595621 m² °⁻¹ Hz⁻¹
#  -1.43362 m² °⁻¹ Hz⁻¹     -1.14536 m² °⁻¹ Hz⁻¹       -1.37246 m² °⁻¹ Hz⁻¹
#  -0.942556 m² °⁻¹ Hz⁻¹    -0.18491 m² °⁻¹ Hz⁻¹        0.586892 m² °⁻¹ Hz⁻¹
#   0.439572 m² °⁻¹ Hz⁻¹     0.176094 m² °⁻¹ Hz⁻¹      -0.0542542 m² °⁻¹ Hz⁻¹
#  -1.35081 m² °⁻¹ Hz⁻¹      0.229892 m² °⁻¹ Hz⁻¹   …   1.56924 m² °⁻¹ Hz⁻¹
#   0.00330667 m² °⁻¹ Hz⁻¹  -0.0420561 m² °⁻¹ Hz⁻¹      1.51802 m² °⁻¹ Hz⁻¹
#  -0.0895223 m² °⁻¹ Hz⁻¹    0.233871 m² °⁻¹ Hz⁻¹      -0.517284 m² °⁻¹ Hz⁻¹
#  -0.378167 m² °⁻¹ Hz⁻¹    -0.202933 m² °⁻¹ Hz⁻¹       1.18749 m² °⁻¹ Hz⁻¹
#   0.535856 m² °⁻¹ Hz⁻¹    -1.43315 m² °⁻¹ Hz⁻¹        0.152368 m² °⁻¹ Hz⁻¹
#   0.0147031 m² °⁻¹ Hz⁻¹    0.752274 m² °⁻¹ Hz⁻¹   …  -0.122472 m² °⁻¹ Hz⁻¹
#   0.677909 m² °⁻¹ Hz⁻¹    -0.394799 m² °⁻¹ Hz⁻¹       2.75525 m² °⁻¹ Hz⁻¹
#  -0.718955 m² °⁻¹ Hz⁻¹    -0.913789 m² °⁻¹ Hz⁻¹       1.20764 m² °⁻¹ Hz⁻¹
#   0.605835 m² °⁻¹ Hz⁻¹    -0.914187 m² °⁻¹ Hz⁻¹       0.996038 m² °⁻¹ Hz⁻¹
#   0.297985 m² °⁻¹ Hz⁻¹     0.349584 m² °⁻¹ Hz⁻¹      -1.05151 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ## Broadcasting

# %%
S = Spectrum(randn(Nf, Nθ)*m^2/Hz/°, f, θ)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  -0.097775 m² °⁻¹ Hz⁻¹  -0.185337 m² °⁻¹ Hz⁻¹   …  -0.00787878 m² °⁻¹ Hz⁻¹
#   0.570196 m² °⁻¹ Hz⁻¹   0.0870724 m² °⁻¹ Hz⁻¹     -0.545814 m² °⁻¹ Hz⁻¹
#   1.2744 m² °⁻¹ Hz⁻¹    -0.748737 m² °⁻¹ Hz⁻¹      -1.2772 m² °⁻¹ Hz⁻¹
#   1.29665 m² °⁻¹ Hz⁻¹   -1.44128 m² °⁻¹ Hz⁻¹       -0.455852 m² °⁻¹ Hz⁻¹
#   0.555253 m² °⁻¹ Hz⁻¹   0.947575 m² °⁻¹ Hz⁻¹       1.53615 m² °⁻¹ Hz⁻¹
#   0.489155 m² °⁻¹ Hz⁻¹  -1.71737 m² °⁻¹ Hz⁻¹    …   0.755296 m² °⁻¹ Hz⁻¹
#   1.2782 m² °⁻¹ Hz⁻¹    -0.184631 m² °⁻¹ Hz⁻¹      -0.670539 m² °⁻¹ Hz⁻¹
#  -0.824809 m² °⁻¹ Hz⁻¹  -1.08034 m² °⁻¹ Hz⁻¹        0.755914 m² °⁻¹ Hz⁻¹
#   0.134533 m² °⁻¹ Hz⁻¹  -1.2166 m² °⁻¹ Hz⁻¹        -0.820091 m² °⁻¹ Hz⁻¹
#   0.199645 m² °⁻¹ Hz⁻¹  -0.0587446 m² °⁻¹ Hz⁻¹      0.240964 m² °⁻¹ Hz⁻¹
#  -0.187232 m² °⁻¹ Hz⁻¹  -0.735112 m² °⁻¹ Hz⁻¹   …  -1.38426 m² °⁻¹ Hz⁻¹
#  -0.797461 m² °⁻¹ Hz⁻¹  -0.9792 m² °⁻¹ Hz⁻¹         0.704071 m² °⁻¹ Hz⁻¹
#   2.62693 m² °⁻¹ Hz⁻¹   -1.727 m² °⁻¹ Hz⁻¹          2.50597 m² °⁻¹ Hz⁻¹
#  -0.261338 m² °⁻¹ Hz⁻¹  -0.952561 m² °⁻¹ Hz⁻¹       1.04719 m² °⁻¹ Hz⁻¹
#  -1.29769 m² °⁻¹ Hz⁻¹    0.624029 m² °⁻¹ Hz⁻¹      -0.285375 m² °⁻¹ Hz⁻¹
#  -1.29501 m² °⁻¹ Hz⁻¹    0.191909 m² °⁻¹ Hz⁻¹   …  -0.425895 m² °⁻¹ Hz⁻¹
#   0.502122 m² °⁻¹ Hz⁻¹  -0.555328 m² °⁻¹ Hz⁻¹      -0.525703 m² °⁻¹ Hz⁻¹
#   0.38274 m² °⁻¹ Hz⁻¹   -0.246772 m² °⁻¹ Hz⁻¹       1.40415 m² °⁻¹ Hz⁻¹
#  -0.243098 m² °⁻¹ Hz⁻¹   0.732339 m² °⁻¹ Hz⁻¹       1.12359 m² °⁻¹ Hz⁻¹
#   1.19935 m² °⁻¹ Hz⁻¹    0.664565 m² °⁻¹ Hz⁻¹       0.1675 m² °⁻¹ Hz⁻¹

# %%
# omni = integrate(S, :direction)
omni = omnidirectional_spectrum(S)
# Out:
# 20-element OmnidirectionalSpectrum{Quantity{Float64, 𝐋² 𝐓, Unitful.FreeUnits{(Hz⁻¹, m²), 𝐋² 𝐓, nothing}}, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#     2.320934139693131 m² Hz⁻¹
#    60.84812055202625 m² Hz⁻¹
#    65.54154971858989 m² Hz⁻¹
#  -141.19623838983736 m² Hz⁻¹
#    94.6942111206953 m² Hz⁻¹
#    39.67630624142794 m² Hz⁻¹
#   -52.456708366493054 m² Hz⁻¹
#    12.039219592962379 m² Hz⁻¹
#   -32.472369586482024 m² Hz⁻¹
#  -118.00780685818533 m² Hz⁻¹
#   -18.154772943811587 m² Hz⁻¹
#    56.668695003378225 m² Hz⁻¹
#    52.82690236925375 m² Hz⁻¹
#   -20.928739572350338 m² Hz⁻¹
#   101.95022048192922 m² Hz⁻¹
#   -18.60117877933614 m² Hz⁻¹
#    60.77074499189995 m² Hz⁻¹
#    54.867467369143526 m² Hz⁻¹
#    38.58335094161532 m² Hz⁻¹
#     3.6749789856991497 m² Hz⁻¹

# %%
# spread = Spectrum(S ./ omnidirectional_spectrum, S.axis1, S.axis2)
spread = spread_function(S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹,), 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  -0.0421274 °⁻¹   -0.0798546 °⁻¹    …  -0.251465 °⁻¹     -0.00339466 °⁻¹
#   0.00937081 °⁻¹   0.00143098 °⁻¹      -0.0360589 °⁻¹    -0.0089701 °⁻¹
#   0.0194441 °⁻¹   -0.0114239 °⁻¹        0.00621546 °⁻¹   -0.0194868 °⁻¹
#  -0.00918331 °⁻¹   0.0102076 °⁻¹        0.00785285 °⁻¹    0.0032285 °⁻¹
#   0.00586364 °⁻¹   0.0100067 °⁻¹        0.00974069 °⁻¹    0.0162223 °⁻¹
#   0.0123286 °⁻¹   -0.0432845 °⁻¹    …  -0.00866602 °⁻¹    0.0190365 °⁻¹
#  -0.0243668 °⁻¹    0.00351969 °⁻¹      -0.0168464 °⁻¹     0.0127827 °⁻¹
#  -0.0685102 °⁻¹   -0.089735 °⁻¹         0.0660111 °⁻¹     0.0627876 °⁻¹
#  -0.004143 °⁻¹     0.0374655 °⁻¹       -0.00238724 °⁻¹    0.025255 °⁻¹
#  -0.00169179 °⁻¹   0.000497803 °⁻¹      0.0213323 °⁻¹    -0.00204193 °⁻¹
#   0.0103131 °⁻¹    0.0404914 °⁻¹    …  -0.113626 °⁻¹      0.0762478 °⁻¹
#  -0.0140723 °⁻¹   -0.0172794 °⁻¹       -0.0246578 °⁻¹     0.0124243 °⁻¹
#   0.0497272 °⁻¹   -0.0326918 °⁻¹        0.00302255 °⁻¹    0.0474375 °⁻¹
#   0.012487 °⁻¹     0.0455145 °⁻¹       -0.00233497 °⁻¹   -0.0500361 °⁻¹
#  -0.0127286 °⁻¹    0.00612092 °⁻¹      -0.000347502 °⁻¹  -0.00279916 °⁻¹
#   0.0696197 °⁻¹   -0.010317 °⁻¹     …  -0.0329737 °⁻¹     0.0228961 °⁻¹
#   0.00826256 °⁻¹  -0.00913808 °⁻¹       0.00819562 °⁻¹   -0.00865059 °⁻¹
#   0.00697572 °⁻¹  -0.0044976 °⁻¹       -0.0147086 °⁻¹     0.0255916 °⁻¹
#  -0.00630058 °⁻¹   0.0189807 °⁻¹       -0.0479322 °⁻¹     0.0291211 °⁻¹
#   0.326355 °⁻¹     0.180835 °⁻¹        -0.598505 °⁻¹      0.0455784 °⁻¹

# %%
integrate(spread, :direction)
# Out:
# 20-element OmnidirectionalSpectrum{Float64, Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}:
#  0.9999999999999937
#  1.0
#  0.9999999999999999
#  0.9999999999999999
#  1.0
#  0.9999999999999999
#  1.0000000000000002
#  1.000000000000001
#  0.9999999999999998
#  1.0
#  0.9999999999999999
#  0.9999999999999999
#  1.0
#  1.0
#  1.0000000000000002
#  0.9999999999999998
#  0.9999999999999999
#  1.0000000000000002
#  1.0000000000000002
#  0.9999999999999939

# %%
all(integrate(spread, :direction) .≈ 1)
# Out:
# true

# %%
S_reconstructed = spread .* omni
# Out:
# 20×36 Matrix{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}}:
#  -0.097775 m² °⁻¹ Hz⁻¹  -0.185337 m² °⁻¹ Hz⁻¹   …  -0.00787878 m² °⁻¹ Hz⁻¹
#   0.570196 m² °⁻¹ Hz⁻¹   0.0870724 m² °⁻¹ Hz⁻¹     -0.545814 m² °⁻¹ Hz⁻¹
#   1.2744 m² °⁻¹ Hz⁻¹    -0.748737 m² °⁻¹ Hz⁻¹      -1.2772 m² °⁻¹ Hz⁻¹
#   1.29665 m² °⁻¹ Hz⁻¹   -1.44128 m² °⁻¹ Hz⁻¹       -0.455852 m² °⁻¹ Hz⁻¹
#   0.555253 m² °⁻¹ Hz⁻¹   0.947575 m² °⁻¹ Hz⁻¹       1.53615 m² °⁻¹ Hz⁻¹
#   0.489155 m² °⁻¹ Hz⁻¹  -1.71737 m² °⁻¹ Hz⁻¹    …   0.755296 m² °⁻¹ Hz⁻¹
#   1.2782 m² °⁻¹ Hz⁻¹    -0.184631 m² °⁻¹ Hz⁻¹      -0.670539 m² °⁻¹ Hz⁻¹
#  -0.824809 m² °⁻¹ Hz⁻¹  -1.08034 m² °⁻¹ Hz⁻¹        0.755914 m² °⁻¹ Hz⁻¹
#   0.134533 m² °⁻¹ Hz⁻¹  -1.2166 m² °⁻¹ Hz⁻¹        -0.820091 m² °⁻¹ Hz⁻¹
#   0.199645 m² °⁻¹ Hz⁻¹  -0.0587446 m² °⁻¹ Hz⁻¹      0.240964 m² °⁻¹ Hz⁻¹
#  -0.187232 m² °⁻¹ Hz⁻¹  -0.735112 m² °⁻¹ Hz⁻¹   …  -1.38426 m² °⁻¹ Hz⁻¹
#  -0.797461 m² °⁻¹ Hz⁻¹  -0.9792 m² °⁻¹ Hz⁻¹         0.704071 m² °⁻¹ Hz⁻¹
#   2.62693 m² °⁻¹ Hz⁻¹   -1.727 m² °⁻¹ Hz⁻¹          2.50597 m² °⁻¹ Hz⁻¹
#  -0.261338 m² °⁻¹ Hz⁻¹  -0.952561 m² °⁻¹ Hz⁻¹       1.04719 m² °⁻¹ Hz⁻¹
#  -1.29769 m² °⁻¹ Hz⁻¹    0.624029 m² °⁻¹ Hz⁻¹      -0.285375 m² °⁻¹ Hz⁻¹
#  -1.29501 m² °⁻¹ Hz⁻¹    0.191909 m² °⁻¹ Hz⁻¹   …  -0.425895 m² °⁻¹ Hz⁻¹
#   0.502122 m² °⁻¹ Hz⁻¹  -0.555328 m² °⁻¹ Hz⁻¹      -0.525703 m² °⁻¹ Hz⁻¹
#   0.38274 m² °⁻¹ Hz⁻¹   -0.246772 m² °⁻¹ Hz⁻¹       1.40415 m² °⁻¹ Hz⁻¹
#  -0.243098 m² °⁻¹ Hz⁻¹   0.732339 m² °⁻¹ Hz⁻¹       1.12359 m² °⁻¹ Hz⁻¹
#   1.19935 m² °⁻¹ Hz⁻¹    0.664565 m² °⁻¹ Hz⁻¹       0.1675 m² °⁻¹ Hz⁻¹

# %%
all(S_reconstructed .≈ S)
# Out:
# true

# %% [markdown]
# ### Convert Units

# %%
uconvert.(u"s^-1", S.axis1)
# Out:
# 20-element Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(s⁻¹,), 𝐓⁻¹, nothing}}}:
#  0.0 s⁻¹
#  0.1 s⁻¹
#  0.2 s⁻¹
#  0.3 s⁻¹
#  0.4 s⁻¹
#  0.5 s⁻¹
#  0.6 s⁻¹
#  0.7 s⁻¹
#  0.8 s⁻¹
#  0.9 s⁻¹
#  1.0 s⁻¹
#  1.1 s⁻¹
#  1.2 s⁻¹
#  1.3 s⁻¹
#  1.4 s⁻¹
#  1.5 s⁻¹
#  1.6 s⁻¹
#  1.7 s⁻¹
#  1.8 s⁻¹
#  1.9 s⁻¹

# %%
axesinfo(S)
# Out:
# (((:temporal, :frequency), 𝐓⁻¹), ((:direction, :angle), 𝐀))

# %%
Spectra.axestypes(S)
# Out:
# (:frequency, :direction)

# %%
Spectra.axestypes(Hz)
# Out:
# :frequency

# %%
dimension(unit(S, :axis1))
# Out:
# 𝐓⁻¹

# %%
Tuple(Spectra.axesinfo(S)[i][2] for i∈1:2)
# Out:
# (𝐓⁻¹, 𝐀)

# %%
(Spectra.axesinfo(S)[1][2], Spectra.axesinfo(S)[2][2])
# Out:
# (𝐓⁻¹, 𝐀)

# %%
Spectra.axesinfo(S.axis1)[2]
# Out:
# 𝐓⁻¹

# %%
unit(S, :axis1)
# Out:
# Hz

# %%
dimension(Hz)
# Out:
# 𝐓⁻¹
