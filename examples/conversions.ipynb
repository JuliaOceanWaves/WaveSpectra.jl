# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ### create spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)
S[frequency=1] = zeros(Nθ) * m^2 / Hz / °;
S
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}:
#  0.0 m² °⁻¹ Hz⁻¹          0.0 m² °⁻¹ Hz⁻¹         …  0.0 m² °⁻¹ Hz⁻¹
#  0.78218 m² °⁻¹ Hz⁻¹      0.527116 m² °⁻¹ Hz⁻¹       0.934835 m² °⁻¹ Hz⁻¹
#  1.19458 m² °⁻¹ Hz⁻¹      1.4264 m² °⁻¹ Hz⁻¹         0.678589 m² °⁻¹ Hz⁻¹
#  0.333004 m² °⁻¹ Hz⁻¹     0.259042 m² °⁻¹ Hz⁻¹       0.907704 m² °⁻¹ Hz⁻¹
#  0.378875 m² °⁻¹ Hz⁻¹     1.10539 m² °⁻¹ Hz⁻¹        0.19184 m² °⁻¹ Hz⁻¹
#  0.489116 m² °⁻¹ Hz⁻¹     0.54929 m² °⁻¹ Hz⁻¹     …  0.66514 m² °⁻¹ Hz⁻¹
#  0.224471 m² °⁻¹ Hz⁻¹     0.591055 m² °⁻¹ Hz⁻¹       0.359958 m² °⁻¹ Hz⁻¹
#  0.229032 m² °⁻¹ Hz⁻¹     1.03527 m² °⁻¹ Hz⁻¹        1.37356 m² °⁻¹ Hz⁻¹
#  2.12895 m² °⁻¹ Hz⁻¹      1.19502 m² °⁻¹ Hz⁻¹        0.5218 m² °⁻¹ Hz⁻¹
#  3.01843 m² °⁻¹ Hz⁻¹      0.806826 m² °⁻¹ Hz⁻¹       2.25219 m² °⁻¹ Hz⁻¹
#  2.59434 m² °⁻¹ Hz⁻¹      0.960413 m² °⁻¹ Hz⁻¹    …  2.13004 m² °⁻¹ Hz⁻¹
#  2.63607 m² °⁻¹ Hz⁻¹      1.03747 m² °⁻¹ Hz⁻¹        0.528399 m² °⁻¹ Hz⁻¹
#  1.33123 m² °⁻¹ Hz⁻¹      0.830754 m² °⁻¹ Hz⁻¹       0.3711 m² °⁻¹ Hz⁻¹
#  0.690564 m² °⁻¹ Hz⁻¹     0.64312 m² °⁻¹ Hz⁻¹        0.0896447 m² °⁻¹ Hz⁻¹
#  0.877896 m² °⁻¹ Hz⁻¹     0.328101 m² °⁻¹ Hz⁻¹       0.400093 m² °⁻¹ Hz⁻¹
#  0.301405 m² °⁻¹ Hz⁻¹     0.958006 m² °⁻¹ Hz⁻¹    …  0.314665 m² °⁻¹ Hz⁻¹
#  1.03007 m² °⁻¹ Hz⁻¹      0.00436157 m² °⁻¹ Hz⁻¹     0.515615 m² °⁻¹ Hz⁻¹
#  0.000578823 m² °⁻¹ Hz⁻¹  0.422219 m² °⁻¹ Hz⁻¹       0.542352 m² °⁻¹ Hz⁻¹
#  2.21313 m² °⁻¹ Hz⁻¹      1.28381 m² °⁻¹ Hz⁻¹        1.21269 m² °⁻¹ Hz⁻¹
#  0.318866 m² °⁻¹ Hz⁻¹     0.219954 m² °⁻¹ Hz⁻¹       1.03923 m² °⁻¹ Hz⁻¹

# %% [markdown]
# ### convert

# %%
S_km = uconvert(u"km^2", S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 km² °⁻¹ Hz⁻¹          …  0.0 km² °⁻¹ Hz⁻¹
#  7.8218e-7 km² °⁻¹ Hz⁻¹       9.34835e-7 km² °⁻¹ Hz⁻¹
#  1.19458e-6 km² °⁻¹ Hz⁻¹      6.78589e-7 km² °⁻¹ Hz⁻¹
#  3.33004e-7 km² °⁻¹ Hz⁻¹      9.07704e-7 km² °⁻¹ Hz⁻¹
#  3.78875e-7 km² °⁻¹ Hz⁻¹      1.9184e-7 km² °⁻¹ Hz⁻¹
#  4.89116e-7 km² °⁻¹ Hz⁻¹   …  6.6514e-7 km² °⁻¹ Hz⁻¹
#  2.24471e-7 km² °⁻¹ Hz⁻¹      3.59958e-7 km² °⁻¹ Hz⁻¹
#  2.29032e-7 km² °⁻¹ Hz⁻¹      1.37356e-6 km² °⁻¹ Hz⁻¹
#  2.12895e-6 km² °⁻¹ Hz⁻¹      5.218e-7 km² °⁻¹ Hz⁻¹
#  3.01843e-6 km² °⁻¹ Hz⁻¹      2.25219e-6 km² °⁻¹ Hz⁻¹
#  2.59434e-6 km² °⁻¹ Hz⁻¹   …  2.13004e-6 km² °⁻¹ Hz⁻¹
#  2.63607e-6 km² °⁻¹ Hz⁻¹      5.28399e-7 km² °⁻¹ Hz⁻¹
#  1.33123e-6 km² °⁻¹ Hz⁻¹      3.711e-7 km² °⁻¹ Hz⁻¹
#  6.90564e-7 km² °⁻¹ Hz⁻¹      8.96447e-8 km² °⁻¹ Hz⁻¹
#  8.77896e-7 km² °⁻¹ Hz⁻¹      4.00093e-7 km² °⁻¹ Hz⁻¹
#  3.01405e-7 km² °⁻¹ Hz⁻¹   …  3.14665e-7 km² °⁻¹ Hz⁻¹
#  1.03007e-6 km² °⁻¹ Hz⁻¹      5.15615e-7 km² °⁻¹ Hz⁻¹
#  5.78823e-10 km² °⁻¹ Hz⁻¹     5.42352e-7 km² °⁻¹ Hz⁻¹
#  2.21313e-6 km² °⁻¹ Hz⁻¹      1.21269e-6 km² °⁻¹ Hz⁻¹
#  3.18866e-7 km² °⁻¹ Hz⁻¹      1.03923e-6 km² °⁻¹ Hz⁻¹

# %%
integrate(S), integrate(S_km), upreferred(integrate(S_km))
# Out:
# (504.9449611530115 m², 0.0005049449611530115 km², 504.9449611530115 m²)

# %%
S_rad = uconvert(rad/s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m², rad⁻¹, s), 𝐋² 𝐓 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐓⁻¹, Unitful.FreeUnits{(rad, s⁻¹), 𝐀 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 m² s °⁻¹ rad⁻¹         …  0.0 m² s °⁻¹ rad⁻¹
#  0.124488 m² s °⁻¹ rad⁻¹       0.148784 m² s °⁻¹ rad⁻¹
#  0.190123 m² s °⁻¹ rad⁻¹       0.108001 m² s °⁻¹ rad⁻¹
#  0.0529993 m² s °⁻¹ rad⁻¹      0.144466 m² s °⁻¹ rad⁻¹
#  0.0602998 m² s °⁻¹ rad⁻¹      0.0305324 m² s °⁻¹ rad⁻¹
#  0.0778452 m² s °⁻¹ rad⁻¹   …  0.10586 m² s °⁻¹ rad⁻¹
#  0.0357256 m² s °⁻¹ rad⁻¹      0.0572891 m² s °⁻¹ rad⁻¹
#  0.0364516 m² s °⁻¹ rad⁻¹      0.218608 m² s °⁻¹ rad⁻¹
#  0.338833 m² s °⁻¹ rad⁻¹       0.0830471 m² s °⁻¹ rad⁻¹
#  0.480398 m² s °⁻¹ rad⁻¹       0.358447 m² s °⁻¹ rad⁻¹
#  0.412903 m² s °⁻¹ rad⁻¹    …  0.339006 m² s °⁻¹ rad⁻¹
#  0.419543 m² s °⁻¹ rad⁻¹       0.0840973 m² s °⁻¹ rad⁻¹
#  0.211872 m² s °⁻¹ rad⁻¹       0.0590624 m² s °⁻¹ rad⁻¹
#  0.109907 m² s °⁻¹ rad⁻¹       0.0142674 m² s °⁻¹ rad⁻¹
#  0.139722 m² s °⁻¹ rad⁻¹       0.0636768 m² s °⁻¹ rad⁻¹
#  0.0479702 m² s °⁻¹ rad⁻¹   …  0.0500805 m² s °⁻¹ rad⁻¹
#  0.163941 m² s °⁻¹ rad⁻¹       0.0820627 m² s °⁻¹ rad⁻¹
#  9.21225e-5 m² s °⁻¹ rad⁻¹     0.086318 m² s °⁻¹ rad⁻¹
#  0.352231 m² s °⁻¹ rad⁻¹       0.193006 m² s °⁻¹ rad⁻¹
#  0.0507492 m² s °⁻¹ rad⁻¹      0.165399 m² s °⁻¹ rad⁻¹

# %%
integrate(S_rad)
# Out:
# 504.94496115301155 m²

# %%
S_T = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  1.15111 m² °⁻¹ s⁻¹    0.794033 m² °⁻¹ s⁻¹    …  3.75162 m² °⁻¹ s⁻¹
#  7.17054 m² °⁻¹ s⁻¹    4.15954 m² °⁻¹ s⁻¹        3.92912 m² °⁻¹ s⁻¹
#  0.0016728 m² °⁻¹ s⁻¹  1.22021 m² °⁻¹ s⁻¹        1.5674 m² °⁻¹ s⁻¹
#  2.63699 m² °⁻¹ s⁻¹    0.0111656 m² °⁻¹ s⁻¹      1.31998 m² °⁻¹ s⁻¹
#  0.678162 m² °⁻¹ s⁻¹   2.15551 m² °⁻¹ s⁻¹        0.707997 m² °⁻¹ s⁻¹
#  1.72068 m² °⁻¹ s⁻¹    0.643077 m² °⁻¹ s⁻¹    …  0.784182 m² °⁻¹ s⁻¹
#  1.16705 m² °⁻¹ s⁻¹    1.08687 m² °⁻¹ s⁻¹        0.1515 m² °⁻¹ s⁻¹
#  1.91697 m² °⁻¹ s⁻¹    1.19629 m² °⁻¹ s⁻¹        0.534384 m² °⁻¹ s⁻¹
#  3.18964 m² °⁻¹ s⁻¹    1.25533 m² °⁻¹ s⁻¹        0.639362 m² °⁻¹ s⁻¹
#  2.59434 m² °⁻¹ s⁻¹    0.960413 m² °⁻¹ s⁻¹       2.13004 m² °⁻¹ s⁻¹
#  2.44493 m² °⁻¹ s⁻¹    0.653529 m² °⁻¹ s⁻¹    …  1.82427 m² °⁻¹ s⁻¹
#  1.36253 m² °⁻¹ s⁻¹    0.764815 m² °⁻¹ s⁻¹       0.333952 m² °⁻¹ s⁻¹
#  0.112226 m² °⁻¹ s⁻¹   0.507281 m² °⁻¹ s⁻¹       0.673043 m² °⁻¹ s⁻¹
#  0.0808094 m² °⁻¹ s⁻¹  0.21278 m² °⁻¹ s⁻¹        0.129585 m² °⁻¹ s⁻¹
#  0.122279 m² °⁻¹ s⁻¹   0.137322 m² °⁻¹ s⁻¹       0.166285 m² °⁻¹ s⁻¹
#  0.0606199 m² °⁻¹ s⁻¹  0.176863 m² °⁻¹ s⁻¹    …  0.0306945 m² °⁻¹ s⁻¹
#  0.0299704 m² °⁻¹ s⁻¹  0.0233138 m² °⁻¹ s⁻¹      0.0816934 m² °⁻¹ s⁻¹
#  0.0477832 m² °⁻¹ s⁻¹  0.0570561 m² °⁻¹ s⁻¹      0.0271435 m² °⁻¹ s⁻¹
#  0.0078218 m² °⁻¹ s⁻¹  0.00527116 m² °⁻¹ s⁻¹     0.00934835 m² °⁻¹ s⁻¹
#  0.0 m² °⁻¹ s⁻¹        0.0 m² °⁻¹ s⁻¹            0.0 m² °⁻¹ s⁻¹

# %%
integrate(S_T[period=1:(Nf-1)])
# Out:
# 501.62395217191863 m²

# %%
S_lin_freq = uconvert(Hz, :axis1, S)
integrate(S_lin_freq)
# Out:
# 504.9449611530115 m²

# %%
S_T_2 = uconvert(s, :axis1, S_rad)
integrate(S_T_2[period=1:(Nf-1)])
# Out:
# 501.62395217191863 m²

# %%
S_T_3 = uconvert(s/rad, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², rad, s⁻¹), 𝐋² 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓 𝐀⁻¹, Unitful.FreeUnits{(rad⁻¹, s), 𝐓 𝐀⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#   7.23262 m² rad °⁻¹ s⁻¹    …  23.5721 m² rad °⁻¹ s⁻¹
#  45.0539 m² rad °⁻¹ s⁻¹        24.6874 m² rad °⁻¹ s⁻¹
#   0.0105105 m² rad °⁻¹ s⁻¹      9.84825 m² rad °⁻¹ s⁻¹
#  16.5687 m² rad °⁻¹ s⁻¹         8.29365 m² rad °⁻¹ s⁻¹
#   4.26102 m² rad °⁻¹ s⁻¹        4.44848 m² rad °⁻¹ s⁻¹
#  10.8113 m² rad °⁻¹ s⁻¹     …   4.92716 m² rad °⁻¹ s⁻¹
#   7.33281 m² rad °⁻¹ s⁻¹        0.9519 m² rad °⁻¹ s⁻¹
#  12.0447 m² rad °⁻¹ s⁻¹         3.35763 m² rad °⁻¹ s⁻¹
#  20.0411 m² rad °⁻¹ s⁻¹         4.01723 m² rad °⁻¹ s⁻¹
#  16.3007 m² rad °⁻¹ s⁻¹        13.3834 m² rad °⁻¹ s⁻¹
#  15.3619 m² rad °⁻¹ s⁻¹     …  11.4622 m² rad °⁻¹ s⁻¹
#   8.56102 m² rad °⁻¹ s⁻¹        2.09828 m² rad °⁻¹ s⁻¹
#   0.705136 m² rad °⁻¹ s⁻¹       4.22885 m² rad °⁻¹ s⁻¹
#   0.50774 m² rad °⁻¹ s⁻¹        0.814206 m² rad °⁻¹ s⁻¹
#   0.768301 m² rad °⁻¹ s⁻¹       1.0448 m² rad °⁻¹ s⁻¹
#   0.380886 m² rad °⁻¹ s⁻¹   …   0.192859 m² rad °⁻¹ s⁻¹
#   0.188309 m² rad °⁻¹ s⁻¹       0.513295 m² rad °⁻¹ s⁻¹
#   0.300231 m² rad °⁻¹ s⁻¹       0.170548 m² rad °⁻¹ s⁻¹
#   0.0491458 m² rad °⁻¹ s⁻¹      0.0587374 m² rad °⁻¹ s⁻¹
#   0.0 m² rad °⁻¹ s⁻¹            0.0 m² rad °⁻¹ s⁻¹

# %%
integrate(S_T_3[angular_period=1:Nf-1])
# Out:
# 501.62395217191863 m²

# %%
S_m = uconvert(m, :axis1, S, deepwater)
# Out:
# KeyError: key (𝐓⁻¹, 𝐋) not found
#
#
#
# Stacktrace:
#
#  [1] getindex
#
#    @ ./dict.jl:498 [inlined]
#
#  [2] getindex(::Dict{Tuple{Unitful.Dimensions, Unitful.Dimensions}, Function}, ::Unitful.Dimensions{(Unitful.Dimension{:Time}(-1//1),)}, ::Unitful.Dimensions{(Unitful.Dimension{:Length}(1//1),)})
#
#    @ Base ./abstractdict.jl:553
#
#  [3] uconvert(uq::Unitful.FreeUnits{(m²,), 𝐋², nothing}, u1::Unitful.FreeUnits{(m,), 𝐋, nothing}, u2::Unitful.FreeUnits{(°,), 𝐀, nothing}, x::Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra ~/repos/JuliaOceanWaves/WaveSpectra/src/convert.jl:15
#
#  [4] uconvert(u::Unitful.FreeUnits{(m,), 𝐋, nothing}, s::Symbol, x::Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra ~/repos/JuliaOceanWaves/WaveSpectra/src/convert.jl:47
#
#  [5] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/WaveSpectra/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X53sZmlsZQ==.jl:1
