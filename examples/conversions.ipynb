# %%
using Unitful
using DimensionfulAngles
using DimensionfulAngles.DefaultSymbols
using AxisArrays

push!(LOAD_PATH, "../src")
using Spectra

# %% [markdown]
# ### create spectrum

# %%
Nf = 20
Δf = 0.1Hz
f = (0:Nf-1) * Δf

Nθ = 36
Δθ = 360° / Nθ
θ = (0:Nθ-1) * Δθ

S = Spectrum(abs.(randn(Nf, Nθ) .+ 0.01) * m^2 / Hz / °, f, θ)
S[frequency=1] = zeros(Nθ) * m^2 / Hz / °;

# %% [markdown]
# ### convert

# %%
S_km = uconvert(u"km^2", S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, km²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 km² °⁻¹ Hz⁻¹         0.0 km² °⁻¹ Hz⁻¹         …  0.0 km² °⁻¹ Hz⁻¹
#  7.52772e-7 km² °⁻¹ Hz⁻¹  1.12461e-8 km² °⁻¹ Hz⁻¹     8.92258e-7 km² °⁻¹ Hz⁻¹
#  1.29054e-6 km² °⁻¹ Hz⁻¹  8.95403e-8 km² °⁻¹ Hz⁻¹     9.80577e-7 km² °⁻¹ Hz⁻¹
#  1.13675e-6 km² °⁻¹ Hz⁻¹  1.64495e-7 km² °⁻¹ Hz⁻¹     2.64585e-7 km² °⁻¹ Hz⁻¹
#  1.05527e-6 km² °⁻¹ Hz⁻¹  5.79804e-7 km² °⁻¹ Hz⁻¹     3.9592e-7 km² °⁻¹ Hz⁻¹
#  9.87653e-7 km² °⁻¹ Hz⁻¹  1.63444e-7 km² °⁻¹ Hz⁻¹  …  7.73777e-7 km² °⁻¹ Hz⁻¹
#  1.35731e-6 km² °⁻¹ Hz⁻¹  1.17348e-6 km² °⁻¹ Hz⁻¹     7.67069e-7 km² °⁻¹ Hz⁻¹
#  1.40312e-6 km² °⁻¹ Hz⁻¹  2.38083e-7 km² °⁻¹ Hz⁻¹     5.72638e-7 km² °⁻¹ Hz⁻¹
#  6.00392e-7 km² °⁻¹ Hz⁻¹  1.2341e-6 km² °⁻¹ Hz⁻¹      9.39286e-7 km² °⁻¹ Hz⁻¹
#  1.29347e-6 km² °⁻¹ Hz⁻¹  1.82384e-7 km² °⁻¹ Hz⁻¹     8.07243e-7 km² °⁻¹ Hz⁻¹
#  6.14124e-7 km² °⁻¹ Hz⁻¹  3.44672e-7 km² °⁻¹ Hz⁻¹  …  7.20127e-8 km² °⁻¹ Hz⁻¹
#  2.23604e-6 km² °⁻¹ Hz⁻¹  5.67988e-7 km² °⁻¹ Hz⁻¹     5.65392e-7 km² °⁻¹ Hz⁻¹
#  3.479e-7 km² °⁻¹ Hz⁻¹    9.81262e-7 km² °⁻¹ Hz⁻¹     1.44309e-6 km² °⁻¹ Hz⁻¹
#  7.95508e-7 km² °⁻¹ Hz⁻¹  3.34847e-7 km² °⁻¹ Hz⁻¹     8.40296e-7 km² °⁻¹ Hz⁻¹
#  8.83207e-7 km² °⁻¹ Hz⁻¹  9.55862e-7 km² °⁻¹ Hz⁻¹     1.13076e-6 km² °⁻¹ Hz⁻¹
#  1.2443e-6 km² °⁻¹ Hz⁻¹   1.19961e-6 km² °⁻¹ Hz⁻¹  …  1.07492e-7 km² °⁻¹ Hz⁻¹
#  1.91656e-6 km² °⁻¹ Hz⁻¹  5.50066e-7 km² °⁻¹ Hz⁻¹     1.06476e-6 km² °⁻¹ Hz⁻¹
#  1.42558e-6 km² °⁻¹ Hz⁻¹  8.74824e-7 km² °⁻¹ Hz⁻¹     1.24613e-6 km² °⁻¹ Hz⁻¹
#  1.6693e-6 km² °⁻¹ Hz⁻¹   4.88202e-7 km² °⁻¹ Hz⁻¹     1.12939e-6 km² °⁻¹ Hz⁻¹
#  2.94971e-8 km² °⁻¹ Hz⁻¹  1.90294e-7 km² °⁻¹ Hz⁻¹     1.07643e-6 km² °⁻¹ Hz⁻¹

# %%
integrate(S), integrate(S_km), upreferred(integrate(S_km))
# Out:
# (523.8858035423409 m², 0.0005238858035423409 km², 523.8858035423409 m²)

# %%
S_rad = uconvert(rad/s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻², Unitful.FreeUnits{(°⁻¹, m², rad⁻¹, s), 𝐋² 𝐓 𝐀⁻², nothing}}, Vector{Quantity{Float64, 𝐀 𝐓⁻¹, Unitful.FreeUnits{(rad, s⁻¹), 𝐀 𝐓⁻¹, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.0 m² s °⁻¹ rad⁻¹         …  0.0 m² s °⁻¹ rad⁻¹
#  0.119807 m² s °⁻¹ rad⁻¹       0.142007 m² s °⁻¹ rad⁻¹
#  0.205395 m² s °⁻¹ rad⁻¹       0.156064 m² s °⁻¹ rad⁻¹
#  0.18092 m² s °⁻¹ rad⁻¹        0.04211 m² s °⁻¹ rad⁻¹
#  0.167951 m² s °⁻¹ rad⁻¹       0.0630126 m² s °⁻¹ rad⁻¹
#  0.15719 m² s °⁻¹ rad⁻¹     …  0.12315 m² s °⁻¹ rad⁻¹
#  0.216023 m² s °⁻¹ rad⁻¹       0.122083 m² s °⁻¹ rad⁻¹
#  0.223313 m² s °⁻¹ rad⁻¹       0.0911381 m² s °⁻¹ rad⁻¹
#  0.0955554 m² s °⁻¹ rad⁻¹      0.149492 m² s °⁻¹ rad⁻¹
#  0.205862 m² s °⁻¹ rad⁻¹       0.128477 m² s °⁻¹ rad⁻¹
#  0.0977408 m² s °⁻¹ rad⁻¹   …  0.0114612 m² s °⁻¹ rad⁻¹
#  0.355877 m² s °⁻¹ rad⁻¹       0.0899849 m² s °⁻¹ rad⁻¹
#  0.05537 m² s °⁻¹ rad⁻¹        0.229674 m² s °⁻¹ rad⁻¹
#  0.126609 m² s °⁻¹ rad⁻¹       0.133737 m² s °⁻¹ rad⁻¹
#  0.140567 m² s °⁻¹ rad⁻¹       0.179966 m² s °⁻¹ rad⁻¹
#  0.198036 m² s °⁻¹ rad⁻¹    …  0.0171079 m² s °⁻¹ rad⁻¹
#  0.305031 m² s °⁻¹ rad⁻¹       0.169461 m² s °⁻¹ rad⁻¹
#  0.226888 m² s °⁻¹ rad⁻¹       0.198328 m² s °⁻¹ rad⁻¹
#  0.265677 m² s °⁻¹ rad⁻¹       0.179748 m² s °⁻¹ rad⁻¹
#  0.00469461 m² s °⁻¹ rad⁻¹     0.171319 m² s °⁻¹ rad⁻¹

# %%
integrate(S_rad)
# Out:
# 523.8858035423409 m²

# %%
S_T = uconvert(s, :axis1, S)
# Out:
# 20×36 Spectrum{Quantity{Float64, 𝐋² 𝐀⁻¹ 𝐓⁻¹, Unitful.FreeUnits{(°⁻¹, m², s⁻¹), 𝐋² 𝐀⁻¹ 𝐓⁻¹, nothing}}, Vector{Quantity{Float64, 𝐓, Unitful.FreeUnits{(s,), 𝐓, nothing}}}, Vector{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}}:
#  0.106484 m² °⁻¹ s⁻¹    0.686961 m² °⁻¹ s⁻¹     …  3.88592 m² °⁻¹ s⁻¹
#  5.40853 m² °⁻¹ s⁻¹     1.58177 m² °⁻¹ s⁻¹         3.65922 m² °⁻¹ s⁻¹
#  4.11993 m² °⁻¹ s⁻¹     2.52824 m² °⁻¹ s⁻¹         3.60132 m² °⁻¹ s⁻¹
#  4.9064 m² °⁻¹ s⁻¹      1.40817 m² °⁻¹ s⁻¹         2.72578 m² °⁻¹ s⁻¹
#  2.79967 m² °⁻¹ s⁻¹     2.69913 m² °⁻¹ s⁻¹         0.241857 m² °⁻¹ s⁻¹
#  1.73109 m² °⁻¹ s⁻¹     1.87349 m² °⁻¹ s⁻¹      …  2.21628 m² °⁻¹ s⁻¹
#  1.34441 m² °⁻¹ s⁻¹     0.565891 m² °⁻¹ s⁻¹        1.4201 m² °⁻¹ s⁻¹
#  0.500976 m² °⁻¹ s⁻¹    1.41302 m² °⁻¹ s⁻¹         2.07804 m² °⁻¹ s⁻¹
#  2.70561 m² °⁻¹ s⁻¹     0.687265 m² °⁻¹ s⁻¹        0.684124 m² °⁻¹ s⁻¹
#  0.614124 m² °⁻¹ s⁻¹    0.344672 m² °⁻¹ s⁻¹        0.0720127 m² °⁻¹ s⁻¹
#  1.04771 m² °⁻¹ s⁻¹     0.147731 m² °⁻¹ s⁻¹     …  0.653867 m² °⁻¹ s⁻¹
#  0.384251 m² °⁻¹ s⁻¹    0.789825 m² °⁻¹ s⁻¹        0.601143 m² °⁻¹ s⁻¹
#  0.687527 m² °⁻¹ s⁻¹    0.116661 m² °⁻¹ s⁻¹        0.280592 m² °⁻¹ s⁻¹
#  0.488632 m² °⁻¹ s⁻¹    0.422453 m² °⁻¹ s⁻¹        0.276145 m² °⁻¹ s⁻¹
#  0.246913 m² °⁻¹ s⁻¹    0.0408609 m² °⁻¹ s⁻¹       0.193444 m² °⁻¹ s⁻¹
#  0.168843 m² °⁻¹ s⁻¹    0.0927686 m² °⁻¹ s⁻¹    …  0.0633472 m² °⁻¹ s⁻¹
#  0.102308 m² °⁻¹ s⁻¹    0.0148046 m² °⁻¹ s⁻¹       0.0238127 m² °⁻¹ s⁻¹
#  0.0516214 m² °⁻¹ s⁻¹   0.00358161 m² °⁻¹ s⁻¹      0.0392231 m² °⁻¹ s⁻¹
#  0.00752772 m² °⁻¹ s⁻¹  0.000112461 m² °⁻¹ s⁻¹     0.00892258 m² °⁻¹ s⁻¹
#  0.0 m² °⁻¹ s⁻¹         0.0 m² °⁻¹ s⁻¹             0.0 m² °⁻¹ s⁻¹

# %%
integrate(S_T[period=1:(Nf-1)])
# Out:
# 527.0105957267451 m²

# %%
S_m = uconvert(m, :axis1, S, deepwater)
# Out:
# KeyError: key (𝐓⁻¹, 𝐋) not found
#
#
#
# Stacktrace:
#
#  [1] getindex
#
#    @ ./dict.jl:498 [inlined]
#
#  [2] getindex(::Dict{Tuple{Unitful.Dimensions, Unitful.Dimensions}, Function}, ::Unitful.Dimensions{(Unitful.Dimension{:Time}(-1//1),)}, ::Unitful.Dimensions{(Unitful.Dimension{:Length}(1//1),)})
#
#    @ Base ./abstractdict.jl:553
#
#  [3] uconvert(uq::Unitful.FreeUnits{(m²,), 𝐋², nothing}, u1::Unitful.FreeUnits{(m,), 𝐋, nothing}, u2::Unitful.FreeUnits{(°,), 𝐀, nothing}, x::Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/convert.jl:15
#
#  [4] uconvert(u::Unitful.FreeUnits{(m,), 𝐋, nothing}, s::Symbol, x::Spectrum{Quantity{Float64, 𝐋² 𝐓 𝐀⁻¹, Unitful.FreeUnits{(°⁻¹, Hz⁻¹, m²), 𝐋² 𝐓 𝐀⁻¹, nothing}}, StepRangeLen{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐓⁻¹, Unitful.FreeUnits{(Hz,), 𝐓⁻¹, nothing}}}, Int64}, StepRangeLen{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Base.TwicePrecision{Quantity{Float64, 𝐀, Unitful.FreeUnits{(°,), 𝐀, nothing}}}, Int64}}, dispersion::Dispersion)
#
#    @ Spectra ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/src/convert.jl:51
#
#  [5] top-level scope
#
#    @ ~/repos/JuliaOceanWaves/JuliaOceanWaves/packages/Spectra.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X41sZmlsZQ==.jl:1
